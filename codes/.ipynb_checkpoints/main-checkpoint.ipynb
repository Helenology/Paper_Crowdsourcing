# %%
# basic (built-in) Python packages
import numpy as np
from numpy.linalg import norm
import pandas as pd
import matplotlib.pyplot as plt

# advanced (built-in) Python packages
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from scipy.optimize import minimize

# my implemented Python functions and classes
from data.generate_data import generate_data
from model.MLE import MLE
from model.OS import OS
from model.ORACLE import ORACLE
from model.Initial import Initial
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # Hyperparameters

# %%
seed = 1
np.random.seed(seed=seed)

N = 100000        # the size of the unlabeled dataset
n = 10000            # pilot sample size
alpha = 1 # n**(-0.1)  
print(f"alpha={alpha:.4f}")

p = 10          # feature dimension
K = 2           # (K+1) classes
M = 100 #int(n / np.log(n))          # the size of the annotator pool
print(f"[n*alpha={int(n*alpha)}/N={N}]")
print(f"[M={M}] vs [n*alpha={int(n*alpha)}]")
# Out:
# alpha=1.0000
# [n*alpha=10000/N=100000]
# [M=100] vs [n*alpha=10000]

# %% [markdown]
# # Data Generation

# %%
beta, sigma_list, theta, X, Y, X1, X2, Y1, Y2, A1, AY1 = generate_data(K, p, N, n, M, alpha, seed=0)
# Out:
# True Labels 1    39315
# 0    33292
# 2    27393
# dtype: int64

# %%
A1.shape
# Out:
# (10000, 100)

# %%
sigma_list
# Out:
# array([0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 , 0.22, 0.24, 0.26, 0.28, 0.3 ,
#        0.32, 0.34, 0.36, 0.38, 0.4 , 0.42, 0.44, 0.46, 0.48, 0.5 , 0.52,
#        0.54, 0.56, 0.58, 0.6 , 0.62, 0.64, 0.66, 0.68, 0.7 , 0.72, 0.74,
#        0.76, 0.78, 0.8 , 0.82, 0.84, 0.86, 0.88, 0.9 , 0.92, 0.94, 0.96,
#        0.98, 1.  , 1.02, 1.04, 1.06, 1.08, 1.1 , 1.12, 1.14, 1.16, 1.18,
#        1.2 , 1.22, 1.24, 1.26, 1.28, 1.3 , 1.32, 1.34, 1.36, 1.38, 1.4 ,
#        1.42, 1.44, 1.46, 1.48, 1.5 , 1.52, 1.54, 1.56, 1.58, 1.6 , 1.62,
#        1.64, 1.66, 1.68, 1.7 , 1.72, 1.74, 1.76, 1.78, 1.8 , 1.82, 1.84,
#        1.86, 1.88, 1.9 , 1.92, 1.94, 1.96, 1.98, 2.  , 2.02, 2.04, 2.06,
#        2.08])

# %% [markdown]
# # Initial Estimator

# %%
init_model = Initial(X1, AY1, A1, K)
init_beta, init_sigma, init_betams = init_model.init_param()
print(norm(init_beta - beta[1:]), norm(init_sigma - sigma_list))

init_sigma /= norm(init_beta)
init_beta /= norm(init_beta)
print(norm(init_beta - beta[1:]), norm(init_sigma - sigma_list))
# Out:
# 0.010661400160411226 0.38169179826297167
# 0.010118655403870878 0.3810874450311234

# %%
diff_mom, diff_son = init_model.check(init_beta, init_sigma, beta[1:], sigma_list)

# %%
plt.boxplot([diff_mom, -diff_son.ravel()])
plt.show()

# %% [markdown]
# # One Step Update

# %%
os_model = OS(X1, AY1, A1, K, init_beta, init_sigma)
os_beta, os_sigma = os_model.NR_alg(max_steps=1, sig=0.1, lbd=0.001, penalty=False, 
                                    true_beta=beta[1:].ravel())
# Out:
# ######## [Step 0] ########
# norm(gradient): 0.0212505
# RMSE(beta): 0.1635351
# eq_violance: 0.1649501

# %%
diff_mom, diff_son = os_model.check(init_beta, init_sigma, beta[1:], sigma_list)

# %%
plt.boxplot([diff_mom.ravel(), diff_son.ravel(), diff_mom.ravel() - diff_son.ravel()])
plt.show()

# %% [markdown]
# - Raw:

# %%
norm(os_beta - beta[1:].ravel()), norm(os_sigma - sigma_list)
# Out:
# (0.018050971614884087, 5.875853662848031)

# %% [markdown]
# - Rescale:

# %%
os_scale = norm(os_beta); print(os_scale)
os_beta /= os_scale
os_sigma /= os_scale
norm(os_beta - beta[1:].ravel()), norm(os_sigma - sigma_list)
# Out:
# 0.984506843224264
# (0.00933541088390242, 5.383561418635815)

# %% [markdown]
# # MLE

# %%
mle_model = MLE(X1, AY1, A1, K, init_beta, init_sigma)
mle_beta, mle_sigma = mle_model.NR_alg(max_steps=10, tol=1e-5, sig=0.1, lbd=0.001, rho=2,
                                       off_diag=False, true_beta=beta[1:].ravel())
# Out:
# ######## [Step 0] ########
# norm(gradient): 0.5923175
# RMSE(beta): 0.0178875
# eq_violance: 0.0150857
# ######## [Step 1] ########
# norm(gradient): 0.3303612
# RMSE(beta): 0.0447534
# eq_violance: 0.0432463
# ######## [Step 2] ########
# norm(gradient): 0.2903219
# RMSE(beta): 0.0191398
# eq_violance: 0.0178162
# ######## [Step 3] ########
# norm(gradient): 0.3142477
# RMSE(beta): 0.0420663
# eq_violance: 0.0403690
# ######## [Step 4] ########
# norm(gradient): 0.2482767
# RMSE(beta): 0.0200469
# eq_violance: 0.0186994
# ######## [Step 5] ########
# norm(gradient): 0.2674987
# RMSE(beta): 0.0328334
# eq_violance: 0.0298501
# ######## [Step 6] ########
# norm(gradient): 0.1534200
# RMSE(beta): 0.0180608
# eq_violance: 0.0162097
# ######## [Step 7] ########
# norm(gradient): 0.1680776
# RMSE(beta): 0.0220547
# eq_violance: 0.0161685
# ######## [Step 8] ########
# norm(gradient): 0.0652120
# RMSE(beta): 0.0136888
# eq_violance: 0.0105497
# ######## [Step 9] ########
# ...

# %%
norm(mle_beta.ravel() - beta[1:].ravel()), norm(mle_sigma - sigma_list)
# Out:
# (0.34068976099635523, 2682.405859709289)

# %% [markdown]
# - Rescale:

# %%
mle_scale = norm(mle_beta)
print(mle_scale)
mle_beta /= mle_scale
mle_sigma /= mle_scale
norm(mle_beta.ravel() - beta[1:].ravel()), norm(mle_sigma - sigma_list)
# Out:
# 0.7439367730310846
# (0.260544893039261, 3611.9924241248227)

# %% [markdown]
# # Oracle

# %%
oracle_model = ORACLE(X1, AY1, A1, K, os_beta.reshape(K, p), sigma_list)
oracle_beta = oracle_model.NR_alg(max_steps=10, tol=1e-7, off_diag=False, 
                                  true_beta=beta[1:].ravel())
# Out:
# ######## [Step 0] ########
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/g8/pcvlzrfj0qj3r46v1s41ylvc0000gn/T/ipykernel_53179/1835958604.py in <module>
#       1 oracle_model = ORACLE(X1, AY1, A1, K, os_beta.reshape(K, p), sigma_list)
# ----> 2 oracle_beta = oracle_model.NR_alg(max_steps=10, tol=1e-7, off_diag=False,
#       3                                   true_beta=beta[1:].ravel())
#
# ~/Desktop/光华/ 论文/4-Crowdsourcing/codes/model/ORACLE.py in NR_alg(self, max_steps, tol, off_diag, true_beta)
#     162             print(f"######## [Step {self.steps}] ########")
#     163             # gradient & Hessian
# --> 164             self.gradient, self.Hessian = self.derivative_calcu(order=2, off_diag=off_diag)
#     165             self.gradient = -self.gradient / self.n
#     166             self.Hessian = -self.Hessian / self.n
#
# ...

# %% [markdown]
# - Raw:

# %%
norm(oracle_beta - beta[1:].ravel())
# Out:
# 0.009938670333403725

# %% [markdown]
# - Rescale:

# %%
ora_scale = norm(oracle_beta)
oracle_beta = oracle_beta / ora_scale
norm(oracle_beta - beta[1:].ravel())
# Out:
# 0.009938670333403725

# %% [markdown]
# # Compare

# %%
B = 50
RMSE_results = []

# %% [markdown]
# - Raw (No Scale):

# %%
for seed in range(B):
    RMSE_list = [seed, n, alpha, M, ]
    np.random.seed(seed)
    beta, sigma_list, theta, X, Y, X1, X2, Y1, Y2, A1, AY1 = generate_data(K, p, N, n, M, alpha, seed=seed)

    # Initial Estimator
    print(f"\n########## Initial Estimator ##########")
    # [1. Raw]
    init_model = Initial(X1, AY1, A1, K)
    init_beta, init_sigma = init_model.opt_alg()
    # init_scale = norm(init_beta)
    # init_beta /= init_scale
    # init_sigma /= init_scale
    init_beta_rmse = norm(init_beta.ravel() - beta[1:].ravel())
    init_sigma_rmse = norm(init_sigma - sigma_list)
    RMSE_list += [init_beta_rmse, init_sigma_rmse]
    
    # OS (One-Step) Estimator 
    print(f"\n########## OS Estimator ##########")
    # [1. Raw]
    os_model = OS(X1, AY1, A1, K, init_beta, init_sigma)
    os_beta, os_sigma = os_model.NR_alg(max_steps=1, tol=1e-5, sig=0.1, lbd=0.001, rho=2, penalty=True, true_beta=beta[1:].ravel())
    os_beta_rmse = norm(os_beta - beta[1:].ravel())
    os_sigma_rmse = norm(os_sigma - sigma_list)
    RMSE_list += [os_beta_rmse, os_sigma_rmse]

    # TS (Two-Step) Estimator 
    print(f"\n########## TS Estimator ##########")
    # [1. Raw]
    ts_model = OS(X1, AY1, A1, K, init_beta, init_sigma)
    ts_beta, ts_sigma = ts_model.NR_alg(max_steps=2, tol=1e-5, sig=0.1, lbd=0.001, rho=2, penalty=True, true_beta=beta[1:].ravel())
    ts_beta_rmse = norm(ts_beta - beta[1:].ravel())
    ts_sigma_rmse = norm(ts_sigma - sigma_list)
    RMSE_list += [ts_beta_rmse, ts_sigma_rmse]

    # TrS (Three-Step) Estimator 
    print(f"\n########## TS Estimator ##########")
    # [1. Raw]
    ts_model = OS(X1, AY1, A1, K, init_beta, init_sigma)
    ts_beta, ts_sigma = ts_model.NR_alg(max_steps=3, tol=1e-5, sig=0.1, lbd=0.001, rho=2, penalty=True, true_beta=beta[1:].ravel())
    ts_beta_rmse = norm(ts_beta - beta[1:].ravel())
    ts_sigma_rmse = norm(ts_sigma - sigma_list)
    RMSE_list += [ts_beta_rmse, ts_sigma_rmse]
    
    # MLE NR
    print(f"\n########## MLE(NR) Estimator ##########")
    # [1. Raw]
    mle_model = MLE(X1, AY1, A1, K, init_beta, init_sigma)
    mle_beta, mle_sigma = mle_model.NR_alg(max_steps=25, tol=1e-5, sig=0.1, lbd=0.001, rho=2, penalty=True, off_diag=False, true_beta=beta[1:].ravel())
    mle_beta_rmse = norm(mle_beta - beta[1:].ravel())
    mle_sigma_rmse = norm(mle_sigma - sigma_list)
    RMSE_list += [mle_beta_rmse, mle_sigma_rmse]

    # # MLE Gradient
    # print(f"\n########## MLE(GA) Estimator ##########")
    # mle_model = MLE(X1, AY1, A1, K, init_beta, init_sigma)
    # mle_beta, mle_sigma = mle_model.GA_alg(max_steps=500, tol=1e-5, sig=0.001, lbd=0.01, stepsize=0.002, rho=2,
    #                                       true_beta=beta[1:].ravel())
    # # [1. Raw]
    # mle_beta_rmse = norm(mle_beta - beta[1:].ravel())
    # mle_sigma_rmse = norm(mle_sigma - sigma_list)
    # RMSE_list += [mle_beta_rmse, mle_sigma_rmse]

    # Oracle
    print(f"\n########## ORACLE Estimator ##########")
    # [1. Raw]
    oracle_model = ORACLE(X1, AY1, A1, K, init_beta, sigma_list)
    ora_beta = oracle_model.NR_alg(max_steps=25, tol=1e-7, off_diag=False, 
                                  true_beta=beta[1:].ravel())
    ora_beta_rmse = norm(ora_beta - beta[1:].ravel())
    RMSE_list.append(ora_beta_rmse)

    # Record Results
    RMSE_results.append(RMSE_list)
    a = pd.DataFrame(RMSE_results, 
                     columns=["seed", "n", "alpha", "M",
                              "init_beta_raw", "init_sigma_raw", 
                              "os_beta_raw", "os_sigma_raw",
                              "ts_beta_raw", "ts_sigma_raw",
                              "trs_beta_raw", "trs_sigma_raw",
                              "mle_beta_NR_raw", "mle_sigma_NR_raw",
                              # "mle_beta_GA_raw", "mle_sigma_GA_raw",
                              "oracle_beta_raw",])
    a.to_csv(f"/Users/helenology/Desktop/[M={M}RAW]rmse_data.csv")
# Out:
# True Labels 3    33177
# 1    26674
# 2    22944
# 0    17205
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 0] ########
# norm(gradient): 6.5939445
# RMSE(beta): 0.0114796
# eq_violance: 0.0000000
#
# ########## TS Estimator ##########
# ######## [Step 0] ########
# norm(gradient): 6.5939445
# RMSE(beta): 0.0114796
# eq_violance: 0.0000000
# ######## [Step 1] ########
# norm(gradient): 6.8653809
# RMSE(beta): 0.0145153
# eq_violance: 0.0000000
#
# ########## TS Estimator ##########
# ######## [Step 0] ########
# norm(gradient): 6.5939445
# RMSE(beta): 0.0114796
# eq_violance: 0.0000000
# ######## [Step 1] ########
# norm(gradient): 6.8653809
# RMSE(beta): 0.0145153
# eq_violance: 0.0000000
# ######## [Step 2] ########
# norm(gradient): 0.9076758
# RMSE(beta): 0.0103849
# eq_violance: 0.0000000
#
# ########## MLE(NR) Estimator ##########
# ######## [Step 0] ########
# norm(gradient): 6.5939445
# ...
