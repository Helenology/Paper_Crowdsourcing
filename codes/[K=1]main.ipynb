# %%
# basic (built-in) Python packages
import numpy as np
from numpy.linalg import norm
import pandas as pd
import matplotlib.pyplot as plt

# advanced (built-in) Python packages
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from scipy.optimize import minimize

# my implemented Python functions and classes
from data.generate_data import generate_data
from model.BaseModel import BaseModel
from model.Initial import Initial
from model.OS import OS
from model.MS import MS
from model.ORACLE_beta import ORACLE_beta
from model.ORACLE_sigma import ORACLE_sigma

# %%
def compute_rmse(est, true):
    est = est.ravel()
    true = true.ravel()
    assert est.shape == true.shape
    length = len(est)
    rmse = norm(est - true) / np.sqrt(length)
    return rmse

# %% [markdown]
# # Hyperparameters

# %%
seed = 1
np.random.seed(seed=seed)

N = 2000        # the size of the unlabeled dataset
r = 0.5
n = int(N * r)            # pilot sample size
alpha = 0.5 # n**(-0.1)  
print(f"alpha={alpha:.4f}")

p = 20          # feature dimension
K = 1           # (K+1) classes
M = int(0.5 * int(n / np.log(n)))          # the size of the annotator pool #int(n / np.log(n))
print(f"[n*alpha={int(n*alpha)}/N={N}]")
print(f"[M={M}] vs [n*alpha={int(n*alpha)}]")
# Out:
# alpha=0.5000
# [n*alpha=500/N=2000]
# [M=72] vs [n*alpha=500]

# %% [markdown]
# # Data Generation

# %%
beta, sigma, theta, X, Y, X1, X2, Y1, Y2, A1, AY1 = generate_data(K, p, N, n, M, alpha, seed=0)
# Out:
# True Labels 0    1084
# 1     916
# dtype: int64

# %%
sigma
# Out:
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 2. , 2. , 2. ,
#        2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. ,
#        2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. , 2. ,
#        2. , 2. , 2. , 2. , 2. , 2. , 2. ])

# %% [markdown]
# # Initial Estimator

# %%
init_model = Initial(X1, AY1, A1, K)
init_beta, init_sigma, init_betams = init_model.init_param()

# %%
init_beta_rmse = compute_rmse(init_beta, beta[1:])
init_sigma_rmse = compute_rmse(init_sigma, sigma)
print(f"Init beta:  {init_beta_rmse:.7f}")
print(f"Init sigma: {init_sigma_rmse:.7f}")
# Out:
# Init beta:  0.0058207
# Init sigma: 0.1998974

# %% [markdown]
# # One Step / Two Step / Multiple Step

# %% [markdown]
# - OS:

# %%
os_model = OS(X1, AY1, A1, K, init_beta, init_sigma)
os_beta, os_sigma = os_model.update_alg(max_steps=1, tol=1e-5)

os_beta_rmse = compute_rmse(os_beta, beta[1:])
os_sigma_rmse = compute_rmse(os_sigma, sigma)
print(f"\nOS beta: {os_beta_rmse:.7f}")
print(f"OS sigma: {os_sigma_rmse:.7f}")
# Out:
# ######## [Step 1] ########
# norm(gradient): 1.4860345
#
# OS beta: 0.0061072
# OS sigma: 0.1361674

# %% [markdown]
# - TS:

# %%
ts_model = MS(X1, AY1, A1, K, init_beta, init_sigma)
ts_beta, ts_sigma = ts_model.update_alg(max_steps=2, tol=1e-5, true_beta=beta[1:].ravel())
# Out:
# ######## [Step 1] ########
# norm(gradient): 1.4860345
# RMSE(beta): 0.0273124
# ######## [Step 2] ########
# norm(gradient): 0.1432535
# RMSE(beta): 0.0245739

# %%
ts_beta_rmse = compute_rmse(ts_beta, beta[1:])
ts_sigma_rmse = compute_rmse(ts_sigma, sigma)
print(f"TS beta: {ts_beta_rmse:.7f}")
print(f"TS sigma: {ts_sigma_rmse:.7f}")
# Out:
# TS beta: 0.0054949
# TS sigma: 0.1361674

# %% [markdown]
# - MS:

# %%
ms_model = MS(X1, AY1, A1, K, init_beta, init_sigma)
ms_beta, ms_sigma = ms_model.update_alg(max_steps=3, tol=1e-5, true_beta=beta[1:].ravel(), echo=False)

# %%
ms_beta_rmse = compute_rmse(ms_beta, beta[1:])
ms_sigma_rmse = compute_rmse(ms_sigma, sigma)
print(f"MS beta:  {ms_beta_rmse:.7f}")
print(f"MS sigma: {ms_sigma_rmse:.7f}")
# Out:
# MS beta:  0.0054983
# MS sigma: 0.1361674

# %% [markdown]
# # Oracle_beta

# %%
orab_model = ORACLE_beta(X1, AY1, A1, K, init_beta, sigma)
oracle_beta = orab_model.update_alg(max_steps=5, tol=1e-5, true_beta=beta[1:])

oracle_beta_rmse = compute_rmse(oracle_beta, beta[1:])
print(f"Oracle beta: {oracle_beta_rmse:.7f}")
# Out:
# ######## [Step 1] ########
# norm(gradient): 0.9505189
# RMSE(beta): 0.0264329
# ######## [Step 2] ########
# norm(gradient): 0.0131490
# RMSE(beta): 0.0268268
# ######## [Step 3] ########
# norm(gradient): 0.0000107
# RMSE(beta): 0.0268272
# Oracle beta: 0.0053082

# %%
# diff_mom, diff_son = orabeta_model.check(beta[1:], sigma)
# plt.boxplot([diff_mom, diff_son.ravel()])
# plt.show()

# %% [markdown]
# # Oracle_sigma

# %%
oras_model = ORACLE_sigma(X1, AY1, A1, K, init_beta, init_sigma)
oracle_sigma = oras_model.update_alg(max_steps=10, tol=1e-5, true_sigma=sigma)
# Out:
# ######## [Step 1] ########
# norm(sigma): 0.1412845
# RMSE(sigma): 1.1554190
# ######## [Step 2] ########
# norm(sigma): 0.0259453
# RMSE(sigma): 1.0943676
# ######## [Step 3] ########
# norm(sigma): 0.0017965
# RMSE(sigma): 1.0910246
# ######## [Step 4] ########
# norm(sigma): 0.0000207
# RMSE(sigma): 1.0909568
# ######## [Step 5] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.0909567

# %%
oracle_sigma_rmse = compute_rmse(oracle_sigma, sigma)
print(f"Oracle sigma: {oracle_sigma_rmse:.7f}")
# Out:
# Oracle sigma: 0.1285705

# %% [markdown]
# # Results

# %%
print(f"Init beta: {init_beta_rmse:.7f}")
print(f"OS   beta: {os_beta_rmse:.7f}")
print(f"TS   beta: {ts_beta_rmse:.7f}")
print(f"MS   beta: {ms_beta_rmse:.7f}")
print(f"Ora  beta: {oracle_beta_rmse:.7f}")
# Out:
# Init beta: 0.0058207
# OS   beta: 0.0061072
# TS   beta: 0.0054949
# MS   beta: 0.0054983
# Ora  beta: 0.0053082

# %%
print(f"Init sigma: {init_sigma_rmse:.7f}")
print(f"OS   sigma: {os_sigma_rmse:.7f}")
print(f"TS   sigma: {ts_sigma_rmse:.7f}")
print(f"MS   sigma: {ms_sigma_rmse:.7f}")
print(f"Ora  sigma: {oracle_sigma_rmse:.7f}")
# Out:
# Init sigma: 0.1998974
# OS   sigma: 0.1361674
# TS   sigma: 0.1361674
# MS   sigma: 0.1361674
# Ora  sigma: 0.1285705

# %% [markdown]
# # Compare Experiments

# %%
p = 20                           # feature dimension
K = 1                            # (K+1) classes
r = 0.5

# %%
B = 1000
RMSE_results = []
NAME_results = []

# %%
alpha_list = [0.25, 0.75]
N_list = [2000, 5000, 10000,]

# %%
for N in N_list:
    n = int(N * r)                 # pilot sample size
    M = int(0.5 * n / np.log(n))   # the size of the annotator pool
    
    for alpha in alpha_list:
        print(f"[n*alpha={int(n*alpha)}/N={N}]")
        print(f"[M={M}] vs [n*alpha={int(n*alpha)}]")
        
        for seed in range(0, int(B/2)):
            RMSE_list = [seed, n, alpha, M, K]
            NAME_list = ["seed", "n", "alpha", "M", "K"]
            np.random.seed(seed)
            beta, sigma, theta, X, Y, X1, X2, Y1, Y2, A1, AY1 = generate_data(K, p, N, n, M, alpha, seed=seed)
        
            # Initial Estimator
            print(f"\n########## Initial Estimator ##########")
            init_model = Initial(X1, AY1, A1, K)
            init_beta, init_sigma, init_betams = init_model.init_param()
            init_beta_rmse = compute_rmse(init_beta, beta[1:])
            init_sigma_rmse = compute_rmse(init_sigma, sigma)
            RMSE_list += [init_beta_rmse, init_sigma_rmse]
            NAME_list += ["init_beta", "init_sigma"]
            
            # OS (One-Step) Estimator 
            print(f"\n########## OS Estimator ##########")
            os_model = OS(X1, AY1, A1, K, init_beta, init_sigma)
            os_beta, os_sigma = os_model.update_alg(max_steps=1, tol=1e-5, true_beta=beta[1:].ravel())
            os_beta_rmse = compute_rmse(os_beta, beta[1:])
            os_sigma_rmse = compute_rmse(os_sigma, sigma)
            RMSE_list += [os_beta_rmse, os_sigma_rmse]
            NAME_list += ["os_beta", "os_sigma"]
        
            # TS (Two-Step) Estimator 
            print(f"\n########## TS Estimator ##########")
            ts_model = MS(X1, AY1, A1, K, init_beta, init_sigma)
            ts_beta, ts_sigma = ts_model.update_alg(max_steps=2, tol=1e-5, true_beta=beta[1:].ravel())
            ts_beta_rmse = compute_rmse(ts_beta, beta[1:])
            ts_sigma_rmse = compute_rmse(ts_sigma, sigma)
            RMSE_list += [ts_beta_rmse, ts_sigma_rmse]
            NAME_list += ["ts_beta", "ts_sigma"]
        
            # MS (Multiple-Step) Estimator 
            print(f"\n########## MS Estimator ##########")
            ms_model = MS(X1, AY1, A1, K, init_beta, init_sigma)
            ms_beta, ms_sigma = ms_model.update_alg(max_steps=3, tol=1e-5, true_beta=beta[1:].ravel())
            ms_beta_rmse = compute_rmse(ms_beta, beta[1:])
            ms_sigma_rmse = compute_rmse(ms_sigma, sigma)
            RMSE_list += [ms_beta_rmse, ms_sigma_rmse]
            NAME_list += ["ms_beta", "ms_sigma"]
        
            # Oracle_beta
            print(f"\n########## ORACLE_beta Estimator ##########")
            oracle_model = ORACLE_beta(X1, AY1, A1, K, init_beta, sigma)
            oracle_beta = oracle_model.update_alg(max_steps=10, tol=1e-5, true_beta=beta[1:])
            oracle_beta_rmse = compute_rmse(oracle_beta, beta[1:])
            
            # Oracle_sigma
            print(f"\n########## ORACLE_sigma Estimator ##########")
            oracle_model = ORACLE_sigma(X1, AY1, A1, K, beta[1:], init_sigma)
            oracle_sigma = oracle_model.update_alg(max_steps=10, tol=1e-5, true_sigma=sigma)
            oracle_sigma_rmse = compute_rmse(oracle_sigma, sigma)
            RMSE_list += [oracle_beta_rmse, oracle_sigma_rmse]
            NAME_list += ["oracle_beta", "oracle_sigma"]
        
            # Print Results
            print()
            print(f"Init beta: {init_beta_rmse:.7f}")
            print(f"Ora  beta: {oracle_beta_rmse:.7f}")
            print(f"OS   beta: {os_beta_rmse:.7f}")
            print(f"TS   beta: {ts_beta_rmse:.7f}")
            print(f"MS   beta: {ms_beta_rmse:.7f}")
            print()
            print(f"Init sigma: {init_sigma_rmse:.7f}")
            print(f"Ora  sigma: {oracle_sigma_rmse:.7f}")
            print(f"OS   sigma: {os_sigma_rmse:.7f}")
            print(f"TS   sigma: {ts_sigma_rmse:.7f}")
            print(f"MS   sigma: {ms_sigma_rmse:.7f}")
        
            # Record Results
            RMSE_results.append(RMSE_list)
            a = pd.DataFrame(RMSE_results, columns=NAME_list)
            a.to_csv(f"./results/[K={K}]rmse_data3.csv")
# Out:
# [n*alpha=250/N=2000]
# [M=72] vs [n*alpha=250]
# True Labels 0    1084
# 1     916
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3033490
# RMSE(beta): 0.0187813
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3033490
# RMSE(beta): 0.0187813
# ######## [Step 2] ########
# norm(gradient): 0.3184381
# RMSE(beta): 0.0221279
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3033490
# RMSE(beta): 0.0187813
# ######## [Step 2] ########
# norm(gradient): 0.3184381
# RMSE(beta): 0.0221279
# ######## [Step 3] ########
# norm(gradient): 0.1963616
# RMSE(beta): 0.0217777
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8618527
# RMSE(beta): 0.0243329
# ######## [Step 2] ########
# norm(gradient): 0.0200554
# RMSE(beta): 0.0247440
# ######## [Step 3] ########
# norm(gradient): 0.0000597
# RMSE(beta): 0.0247461
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0247461
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1062831
# RMSE(sigma): 2.1059030
# ######## [Step 2] ########
# norm(sigma): 0.0292691
# RMSE(sigma): 1.9547550
# ######## [Step 3] ########
# norm(sigma): 0.0066232
# RMSE(sigma): 1.9884326
# ######## [Step 4] ########
# norm(sigma): 0.0010230
# RMSE(sigma): 2.0038641
# ######## [Step 5] ########
# norm(sigma): 0.0000475
# RMSE(sigma): 2.0047874
# ######## [Step 6] ########
# norm(sigma): 0.0000001
# RMSE(sigma): 2.0047902
#
# Init beta: 0.0116440
# Ora  beta: 0.0054236
# OS   beta: 0.0041996
# TS   beta: 0.0049480
# MS   beta: 0.0048696
#
# Init sigma: 0.3421373
# Ora  sigma: 0.2362668
# OS   sigma: 0.2463456
# TS   sigma: 0.2463456
# MS   sigma: 0.2463456
# True Labels 0    1032
# 1     968
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.5732833
# RMSE(beta): 0.0406223
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.5732833
# RMSE(beta): 0.0406223
# ######## [Step 2] ########
# norm(gradient): 0.2127227
# RMSE(beta): 0.0266979
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.5732833
# RMSE(beta): 0.0406223
# ######## [Step 2] ########
# norm(gradient): 0.2127227
# RMSE(beta): 0.0266979
# ######## [Step 3] ########
# norm(gradient): 0.0978123
# RMSE(beta): 0.0268039
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9537015
# RMSE(beta): 0.0478240
# ######## [Step 2] ########
# norm(gradient): 0.0270153
# RMSE(beta): 0.0518630
# ######## [Step 3] ########
# norm(gradient): 0.0001149
# RMSE(beta): 0.0518839
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0518839
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0999374
# RMSE(sigma): 2.0006660
# ######## [Step 2] ########
# norm(sigma): 0.0234465
# RMSE(sigma): 1.8090870
# ######## [Step 3] ########
# norm(sigma): 0.0032015
# RMSE(sigma): 1.8076650
# ######## [Step 4] ########
# norm(sigma): 0.0001997
# RMSE(sigma): 1.8094996
# ######## [Step 5] ########
# norm(sigma): 0.0000019
# RMSE(sigma): 1.8095340
#
# Init beta: 0.0165866
# Ora  beta: 0.0060532
# OS   beta: 0.0090834
# TS   beta: 0.0059698
# MS   beta: 0.0059935
#
# Init sigma: 0.3445810
# Ora  sigma: 0.2132556
# OS   sigma: 0.2304261
# TS   sigma: 0.2304261
# MS   sigma: 0.2304261
# True Labels 0    1004
# 1     996
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1568354
# RMSE(beta): 0.0259521
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1568354
# RMSE(beta): 0.0259521
# ######## [Step 2] ########
# norm(gradient): 0.2015566
# RMSE(beta): 0.0235709
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1568354
# RMSE(beta): 0.0259521
# ######## [Step 2] ########
# norm(gradient): 0.2015566
# RMSE(beta): 0.0235709
# ######## [Step 3] ########
# norm(gradient): 0.1592443
# RMSE(beta): 0.0235455
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.5422392
# RMSE(beta): 0.0333931
# ######## [Step 2] ########
# norm(gradient): 0.0105366
# RMSE(beta): 0.0348219
# ######## [Step 3] ########
# norm(gradient): 0.0000195
# RMSE(beta): 0.0348248
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1309624
# RMSE(sigma): 1.7378674
# ######## [Step 2] ########
# norm(sigma): 0.0342394
# RMSE(sigma): 1.6245407
# ######## [Step 3] ########
# norm(sigma): 0.0050649
# RMSE(sigma): 1.6472336
# ######## [Step 4] ########
# norm(sigma): 0.0002472
# RMSE(sigma): 1.6501922
# ######## [Step 5] ########
# norm(sigma): 0.0000018
# RMSE(sigma): 1.6502161
#
# Init beta: 0.0111996
# Ora  beta: 0.0055206
# OS   beta: 0.0058031
# TS   beta: 0.0052706
# MS   beta: 0.0052649
#
# Init sigma: 0.3086528
# Ora  sigma: 0.1944798
# OS   sigma: 0.2007570
# TS   sigma: 0.2007570
# MS   sigma: 0.2007570
# True Labels 0    1047
# 1     953
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1573784
# RMSE(beta): 0.0481914
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1573784
# RMSE(beta): 0.0481914
# ######## [Step 2] ########
# norm(gradient): 0.3498705
# RMSE(beta): 0.0316170
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1573784
# RMSE(beta): 0.0481914
# ######## [Step 2] ########
# norm(gradient): 0.3498705
# RMSE(beta): 0.0316170
# ######## [Step 3] ########
# norm(gradient): 0.2405389
# RMSE(beta): 0.0322444
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6440519
# RMSE(beta): 0.0308293
# ######## [Step 2] ########
# norm(gradient): 0.0220178
# RMSE(beta): 0.0297313
# ######## [Step 3] ########
# norm(gradient): 0.0000738
# RMSE(beta): 0.0297283
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1580984
# RMSE(sigma): 1.6077880
# ######## [Step 2] ########
# norm(sigma): 0.0471115
# RMSE(sigma): 1.3962753
# ######## [Step 3] ########
# norm(sigma): 0.0117012
# RMSE(sigma): 1.3972176
# ######## [Step 4] ########
# norm(sigma): 0.0025556
# RMSE(sigma): 1.3972567
# ######## [Step 5] ########
# norm(sigma): 0.0003086
# RMSE(sigma): 1.3971996
# ######## [Step 6] ########
# norm(sigma): 0.0000064
# RMSE(sigma): 1.3971994
#
# Init beta: 0.0117516
# Ora  beta: 0.0063932
# OS   beta: 0.0107759
# TS   beta: 0.0070698
# MS   beta: 0.0072101
#
# Init sigma: 0.3136980
# Ora  sigma: 0.1646615
# OS   sigma: 0.1885924
# TS   sigma: 0.1885924
# MS   sigma: 0.1885924
# True Labels 0    1033
# 1     967
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4066265
# RMSE(beta): 0.0542148
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4066265
# RMSE(beta): 0.0542148
# ######## [Step 2] ########
# norm(gradient): 0.2599349
# RMSE(beta): 0.0375654
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4066265
# RMSE(beta): 0.0542148
# ######## [Step 2] ########
# norm(gradient): 0.2599349
# RMSE(beta): 0.0375654
# ######## [Step 3] ########
# norm(gradient): 0.1393687
# RMSE(beta): 0.0379855
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8395458
# RMSE(beta): 0.0418930
# ######## [Step 2] ########
# norm(gradient): 0.0224007
# RMSE(beta): 0.0439428
# ######## [Step 3] ########
# norm(gradient): 0.0000824
# RMSE(beta): 0.0439510
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0439510
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1195748
# RMSE(sigma): 1.9098534
# ######## [Step 2] ########
# norm(sigma): 0.0305777
# RMSE(sigma): 1.6805474
# ######## [Step 3] ########
# norm(sigma): 0.0049801
# RMSE(sigma): 1.6685066
# ######## [Step 4] ########
# norm(sigma): 0.0004526
# RMSE(sigma): 1.6693619
# ######## [Step 5] ########
# norm(sigma): 0.0000130
# RMSE(sigma): 1.6693973
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.6693973
#
# Init beta: 0.0074169
# Ora  beta: 0.0079649
# OS   beta: 0.0121228
# TS   beta: 0.0083999
# MS   beta: 0.0084938
#
# Init sigma: 0.3381637
# Ora  sigma: 0.1967404
# OS   sigma: 0.2239179
# TS   sigma: 0.2239179
# MS   sigma: 0.2239179
# True Labels 0    1067
# 1     933
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1504906
# RMSE(beta): 0.0275179
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1504906
# RMSE(beta): 0.0275179
# ######## [Step 2] ########
# norm(gradient): 0.2238925
# RMSE(beta): 0.0280396
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1504906
# RMSE(beta): 0.0275179
# ######## [Step 2] ########
# norm(gradient): 0.2238925
# RMSE(beta): 0.0280396
# ######## [Step 3] ########
# norm(gradient): 0.1681833
# RMSE(beta): 0.0276963
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6481990
# RMSE(beta): 0.0465192
# ######## [Step 2] ########
# norm(gradient): 0.0185588
# RMSE(beta): 0.0485420
# ######## [Step 3] ########
# norm(gradient): 0.0000513
# RMSE(beta): 0.0485487
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0485487
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1200693
# RMSE(sigma): 2.0690068
# ######## [Step 2] ########
# norm(sigma): 0.0330946
# RMSE(sigma): 1.8555283
# ######## [Step 3] ########
# norm(sigma): 0.0071864
# RMSE(sigma): 1.8314545
# ######## [Step 4] ########
# norm(sigma): 0.0010549
# RMSE(sigma): 1.8281789
# ######## [Step 5] ########
# norm(sigma): 0.0000438
# RMSE(sigma): 1.8280195
# ######## [Step 6] ########
# norm(sigma): 0.0000001
# RMSE(sigma): 1.8280193
#
# Init beta: 0.0153719
# Ora  beta: 0.0064634
# OS   beta: 0.0061532
# TS   beta: 0.0062698
# MS   beta: 0.0061931
#
# Init sigma: 0.3479486
# Ora  sigma: 0.2154341
# OS   sigma: 0.2416046
# TS   sigma: 0.2416046
# MS   sigma: 0.2416046
# True Labels 0    1019
# 1     981
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3446124
# RMSE(beta): 0.0350350
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3446124
# RMSE(beta): 0.0350350
# ######## [Step 2] ########
# norm(gradient): 0.3818801
# RMSE(beta): 0.0317478
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3446124
# RMSE(beta): 0.0350350
# ######## [Step 2] ########
# norm(gradient): 0.3818801
# RMSE(beta): 0.0317478
# ######## [Step 3] ########
# norm(gradient): 0.2429945
# RMSE(beta): 0.0319776
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9714512
# RMSE(beta): 0.0457282
# ######## [Step 2] ########
# norm(gradient): 0.0422111
# RMSE(beta): 0.0425681
# ######## [Step 3] ########
# norm(gradient): 0.0001922
# RMSE(beta): 0.0425506
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0425506
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1370035
# RMSE(sigma): 1.6419816
# ######## [Step 2] ########
# norm(sigma): 0.0349557
# RMSE(sigma): 1.5939788
# ######## [Step 3] ########
# norm(sigma): 0.0057065
# RMSE(sigma): 1.6707459
# ######## [Step 4] ########
# norm(sigma): 0.0005180
# RMSE(sigma): 1.6806559
# ######## [Step 5] ########
# norm(sigma): 0.0000133
# RMSE(sigma): 1.6808194
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.6808195
#
# Init beta: 0.0094710
# Ora  beta: 0.0067146
# OS   beta: 0.0078341
# TS   beta: 0.0070990
# MS   beta: 0.0071504
#
# Init sigma: 0.3134447
# Ora  sigma: 0.1980865
# OS   sigma: 0.1949941
# TS   sigma: 0.1949941
# MS   sigma: 0.1949941
# True Labels 1    1062
# 0     938
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4262737
# RMSE(beta): 0.0276899
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4262737
# RMSE(beta): 0.0276899
# ######## [Step 2] ########
# norm(gradient): 0.3032683
# RMSE(beta): 0.0351024
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4262737
# RMSE(beta): 0.0276899
# ######## [Step 2] ########
# norm(gradient): 0.3032683
# RMSE(beta): 0.0351024
# ######## [Step 3] ########
# norm(gradient): 0.1714349
# RMSE(beta): 0.0346549
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9428053
# RMSE(beta): 0.0383348
# ######## [Step 2] ########
# norm(gradient): 0.0357716
# RMSE(beta): 0.0368691
# ######## [Step 3] ########
# norm(gradient): 0.0001831
# RMSE(beta): 0.0368624
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0368624
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1219974
# RMSE(sigma): 1.6544548
# ######## [Step 2] ########
# norm(sigma): 0.0300085
# RMSE(sigma): 1.6893012
# ######## [Step 3] ########
# norm(sigma): 0.0043775
# RMSE(sigma): 1.7326554
# ######## [Step 4] ########
# norm(sigma): 0.0002563
# RMSE(sigma): 1.7364097
# ######## [Step 5] ########
# norm(sigma): 0.0000025
# RMSE(sigma): 1.7364425
#
# Init beta: 0.0153792
# Ora  beta: 0.0076090
# OS   beta: 0.0061917
# TS   beta: 0.0078491
# MS   beta: 0.0077491
#
# Init sigma: 0.2782415
# Ora  sigma: 0.2046417
# OS   sigma: 0.1932305
# TS   sigma: 0.1932305
# MS   sigma: 0.1932305
# True Labels 1    1107
# 0     893
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2075419
# RMSE(beta): 0.0222395
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2075419
# RMSE(beta): 0.0222395
# ######## [Step 2] ########
# norm(gradient): 0.2658600
# RMSE(beta): 0.0221971
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2075419
# RMSE(beta): 0.0222395
# ######## [Step 2] ########
# norm(gradient): 0.2658600
# RMSE(beta): 0.0221971
# ######## [Step 3] ########
# norm(gradient): 0.2380791
# RMSE(beta): 0.0220589
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.5967659
# RMSE(beta): 0.0283605
# ######## [Step 2] ########
# norm(gradient): 0.0236618
# RMSE(beta): 0.0276466
# ######## [Step 3] ########
# norm(gradient): 0.0000698
# RMSE(beta): 0.0276445
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1438285
# RMSE(sigma): 1.7823267
# ######## [Step 2] ########
# norm(sigma): 0.0392699
# RMSE(sigma): 1.7702162
# ######## [Step 3] ########
# norm(sigma): 0.0073789
# RMSE(sigma): 1.8715114
# ######## [Step 4] ########
# norm(sigma): 0.0009493
# RMSE(sigma): 1.8934957
# ######## [Step 5] ########
# norm(sigma): 0.0000632
# RMSE(sigma): 1.8948623
# ######## [Step 6] ########
# norm(sigma): 0.0000004
# RMSE(sigma): 1.8948710
#
# Init beta: 0.0082053
# Ora  beta: 0.0051452
# OS   beta: 0.0049729
# TS   beta: 0.0049634
# MS   beta: 0.0049325
#
# Init sigma: 0.3143410
# Ora  sigma: 0.2233127
# OS   sigma: 0.2104238
# TS   sigma: 0.2104238
# MS   sigma: 0.2104238
# True Labels 1    1027
# 0     973
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1599892
# RMSE(beta): 0.0549935
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1599892
# RMSE(beta): 0.0549935
# ######## [Step 2] ########
# norm(gradient): 0.3029401
# RMSE(beta): 0.0522373
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1599892
# RMSE(beta): 0.0549935
# ######## [Step 2] ########
# norm(gradient): 0.3029401
# RMSE(beta): 0.0522373
# ######## [Step 3] ########
# norm(gradient): 0.2041249
# RMSE(beta): 0.0524000
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7290527
# RMSE(beta): 0.0518606
# ######## [Step 2] ########
# norm(gradient): 0.0129316
# RMSE(beta): 0.0529061
# ######## [Step 3] ########
# norm(gradient): 0.0000286
# RMSE(beta): 0.0529090
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1367482
# RMSE(sigma): 1.7418954
# ######## [Step 2] ########
# norm(sigma): 0.0382818
# RMSE(sigma): 1.4256603
# ######## [Step 3] ########
# norm(sigma): 0.0067307
# RMSE(sigma): 1.4190845
# ######## [Step 4] ########
# norm(sigma): 0.0004159
# RMSE(sigma): 1.4211361
# ######## [Step 5] ########
# norm(sigma): 0.0000033
# RMSE(sigma): 1.4211611
#
# Init beta: 0.0109760
# Ora  beta: 0.0106412
# OS   beta: 0.0122969
# TS   beta: 0.0116806
# MS   beta: 0.0117170
#
# Init sigma: 0.3409370
# Ora  sigma: 0.1674854
# OS   sigma: 0.2084655
# TS   sigma: 0.2084655
# MS   sigma: 0.2084655
# True Labels 0    1123
# 1     877
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4173645
# RMSE(beta): 0.0355019
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4173645
# RMSE(beta): 0.0355019
# ######## [Step 2] ########
# norm(gradient): 0.3173250
# RMSE(beta): 0.0304816
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4173645
# RMSE(beta): 0.0355019
# ######## [Step 2] ########
# norm(gradient): 0.3173250
# RMSE(beta): 0.0304816
# ######## [Step 3] ########
# norm(gradient): 0.2151433
# RMSE(beta): 0.0306840
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9564386
# RMSE(beta): 0.0299150
# ######## [Step 2] ########
# norm(gradient): 0.0166684
# RMSE(beta): 0.0307919
# ######## [Step 3] ########
# norm(gradient): 0.0000439
# RMSE(beta): 0.0307946
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1198943
# RMSE(sigma): 1.7201772
# ######## [Step 2] ########
# norm(sigma): 0.0310931
# RMSE(sigma): 1.6242006
# ######## [Step 3] ########
# norm(sigma): 0.0052394
# RMSE(sigma): 1.7095161
# ######## [Step 4] ########
# norm(sigma): 0.0004154
# RMSE(sigma): 1.7220630
# ######## [Step 5] ########
# norm(sigma): 0.0000059
# RMSE(sigma): 1.7222361
#
# Init beta: 0.0092926
# Ora  beta: 0.0065426
# OS   beta: 0.0079385
# TS   beta: 0.0068159
# MS   beta: 0.0068611
#
# Init sigma: 0.3258605
# Ora  sigma: 0.2029675
# OS   sigma: 0.2063525
# TS   sigma: 0.2063525
# MS   sigma: 0.2063525
# True Labels 1    1050
# 0     950
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3141543
# RMSE(beta): 0.0285817
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3141543
# RMSE(beta): 0.0285817
# ######## [Step 2] ########
# norm(gradient): 0.2882061
# RMSE(beta): 0.0292400
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3141543
# RMSE(beta): 0.0285817
# ######## [Step 2] ########
# norm(gradient): 0.2882061
# RMSE(beta): 0.0292400
# ######## [Step 3] ########
# norm(gradient): 0.2175189
# RMSE(beta): 0.0292452
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9112506
# RMSE(beta): 0.0322362
# ######## [Step 2] ########
# norm(gradient): 0.0221089
# RMSE(beta): 0.0319113
# ######## [Step 3] ########
# norm(gradient): 0.0000563
# RMSE(beta): 0.0319102
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1115226
# RMSE(sigma): 1.7036478
# ######## [Step 2] ########
# norm(sigma): 0.0276938
# RMSE(sigma): 1.4219782
# ######## [Step 3] ########
# norm(sigma): 0.0038412
# RMSE(sigma): 1.4064091
# ######## [Step 4] ########
# norm(sigma): 0.0002054
# RMSE(sigma): 1.4076516
# ######## [Step 5] ########
# norm(sigma): 0.0000019
# RMSE(sigma): 1.4076800
#
# Init beta: 0.0080065
# Ora  beta: 0.0070166
# OS   beta: 0.0063911
# TS   beta: 0.0065383
# MS   beta: 0.0065394
#
# Init sigma: 0.3316127
# Ora  sigma: 0.1658967
# OS   sigma: 0.2001111
# TS   sigma: 0.2001111
# MS   sigma: 0.2001111
# True Labels 1    1037
# 0     963
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4175269
# RMSE(beta): 0.0237840
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4175269
# RMSE(beta): 0.0237840
# ######## [Step 2] ########
# norm(gradient): 0.3301204
# RMSE(beta): 0.0249982
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4175269
# RMSE(beta): 0.0237840
# ######## [Step 2] ########
# norm(gradient): 0.3301204
# RMSE(beta): 0.0249982
# ######## [Step 3] ########
# norm(gradient): 0.2292260
# RMSE(beta): 0.0248628
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8563082
# RMSE(beta): 0.0229923
# ######## [Step 2] ########
# norm(gradient): 0.0197341
# RMSE(beta): 0.0230406
# ######## [Step 3] ########
# norm(gradient): 0.0000583
# RMSE(beta): 0.0230412
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1315713
# RMSE(sigma): 1.5987346
# ######## [Step 2] ########
# norm(sigma): 0.0337924
# RMSE(sigma): 1.3135656
# ######## [Step 3] ########
# norm(sigma): 0.0051815
# RMSE(sigma): 1.3148248
# ######## [Step 4] ########
# norm(sigma): 0.0002870
# RMSE(sigma): 1.3171287
# ######## [Step 5] ########
# norm(sigma): 0.0000020
# RMSE(sigma): 1.3171604
#
# Init beta: 0.0108215
# Ora  beta: 0.0051517
# OS   beta: 0.0053183
# TS   beta: 0.0055898
# MS   beta: 0.0055595
#
# Init sigma: 0.3300126
# Ora  sigma: 0.1552288
# OS   sigma: 0.1892955
# TS   sigma: 0.1892955
# MS   sigma: 0.1892955
# True Labels 0    1028
# 1     972
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4255781
# RMSE(beta): 0.0288818
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4255781
# RMSE(beta): 0.0288818
# ######## [Step 2] ########
# norm(gradient): 0.3956539
# RMSE(beta): 0.0254229
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4255781
# RMSE(beta): 0.0288818
# ######## [Step 2] ########
# norm(gradient): 0.3956539
# RMSE(beta): 0.0254229
# ######## [Step 3] ########
# norm(gradient): 0.2337858
# RMSE(beta): 0.0252723
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9108153
# RMSE(beta): 0.0266733
# ######## [Step 2] ########
# norm(gradient): 0.0245621
# RMSE(beta): 0.0257278
# ######## [Step 3] ########
# norm(gradient): 0.0000970
# RMSE(beta): 0.0257248
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0257248
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1377614
# RMSE(sigma): 2.0966406
# ######## [Step 2] ########
# norm(sigma): 0.0360963
# RMSE(sigma): 1.8365416
# ######## [Step 3] ########
# norm(sigma): 0.0063131
# RMSE(sigma): 1.8029840
# ######## [Step 4] ########
# norm(sigma): 0.0007302
# RMSE(sigma): 1.8018217
# ######## [Step 5] ########
# norm(sigma): 0.0000265
# RMSE(sigma): 1.8017989
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.8017989
#
# Init beta: 0.0105511
# Ora  beta: 0.0056080
# OS   beta: 0.0064582
# TS   beta: 0.0056847
# MS   beta: 0.0056511
#
# Init sigma: 0.3588851
# Ora  sigma: 0.2123440
# OS   sigma: 0.2459403
# TS   sigma: 0.2459403
# MS   sigma: 0.2459403
# True Labels 0    1064
# 1     936
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3057679
# RMSE(beta): 0.0329918
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3057679
# RMSE(beta): 0.0329918
# ######## [Step 2] ########
# norm(gradient): 0.3154955
# RMSE(beta): 0.0220252
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3057679
# RMSE(beta): 0.0329918
# ######## [Step 2] ########
# norm(gradient): 0.3154955
# RMSE(beta): 0.0220252
# ######## [Step 3] ########
# norm(gradient): 0.2041953
# RMSE(beta): 0.0223688
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7249521
# RMSE(beta): 0.0325079
# ######## [Step 2] ########
# norm(gradient): 0.0132632
# RMSE(beta): 0.0341933
# ######## [Step 3] ########
# norm(gradient): 0.0000329
# RMSE(beta): 0.0341980
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1490514
# RMSE(sigma): 1.8101988
# ######## [Step 2] ########
# norm(sigma): 0.0401562
# RMSE(sigma): 1.6622358
# ######## [Step 3] ########
# norm(sigma): 0.0069826
# RMSE(sigma): 1.6675055
# ######## [Step 4] ########
# norm(sigma): 0.0005399
# RMSE(sigma): 1.6677732
# ######## [Step 5] ########
# norm(sigma): 0.0000056
# RMSE(sigma): 1.6677674
#
# Init beta: 0.0082840
# Ora  beta: 0.0054533
# OS   beta: 0.0073772
# TS   beta: 0.0049250
# MS   beta: 0.0050018
#
# Init sigma: 0.3253291
# Ora  sigma: 0.1965483
# OS   sigma: 0.2123979
# TS   sigma: 0.2123979
# MS   sigma: 0.2123979
# True Labels 0    1020
# 1     980
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4363912
# RMSE(beta): 0.0268430
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4363912
# RMSE(beta): 0.0268430
# ######## [Step 2] ########
# norm(gradient): 0.3100487
# RMSE(beta): 0.0250976
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4363912
# RMSE(beta): 0.0268430
# ######## [Step 2] ########
# norm(gradient): 0.3100487
# RMSE(beta): 0.0250976
# ######## [Step 3] ########
# norm(gradient): 0.1845626
# RMSE(beta): 0.0251152
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9257988
# RMSE(beta): 0.0260043
# ######## [Step 2] ########
# norm(gradient): 0.0163584
# RMSE(beta): 0.0260775
# ######## [Step 3] ########
# norm(gradient): 0.0000372
# RMSE(beta): 0.0260781
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1295043
# RMSE(sigma): 1.6883174
# ######## [Step 2] ########
# norm(sigma): 0.0338546
# RMSE(sigma): 1.5314344
# ######## [Step 3] ########
# norm(sigma): 0.0053644
# RMSE(sigma): 1.5295712
# ######## [Step 4] ########
# norm(sigma): 0.0003614
# RMSE(sigma): 1.5310619
# ######## [Step 5] ########
# norm(sigma): 0.0000046
# RMSE(sigma): 1.5310959
#
# Init beta: 0.0066442
# Ora  beta: 0.0058184
# OS   beta: 0.0060023
# TS   beta: 0.0056120
# MS   beta: 0.0056159
#
# Init sigma: 0.3055440
# Ora  sigma: 0.1804414
# OS   sigma: 0.1980535
# TS   sigma: 0.1980535
# MS   sigma: 0.1980535
# True Labels 0    1028
# 1     972
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4326931
# RMSE(beta): 0.0256250
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4326931
# RMSE(beta): 0.0256250
# ######## [Step 2] ########
# norm(gradient): 0.3546256
# RMSE(beta): 0.0203597
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4326931
# RMSE(beta): 0.0256250
# ######## [Step 2] ########
# norm(gradient): 0.3546256
# RMSE(beta): 0.0203597
# ######## [Step 3] ########
# norm(gradient): 0.2222504
# RMSE(beta): 0.0204297
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8941835
# RMSE(beta): 0.0286093
# ######## [Step 2] ########
# norm(gradient): 0.0196917
# RMSE(beta): 0.0307721
# ######## [Step 3] ########
# norm(gradient): 0.0000595
# RMSE(beta): 0.0307800
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0307800
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1286128
# RMSE(sigma): 1.8936923
# ######## [Step 2] ########
# norm(sigma): 0.0329957
# RMSE(sigma): 1.7326824
# ######## [Step 3] ########
# norm(sigma): 0.0049178
# RMSE(sigma): 1.7300790
# ######## [Step 4] ########
# norm(sigma): 0.0002592
# RMSE(sigma): 1.7288799
# ######## [Step 5] ########
# norm(sigma): 0.0000016
# RMSE(sigma): 1.7288628
#
# Init beta: 0.0077773
# Ora  beta: 0.0048075
# OS   beta: 0.0057299
# TS   beta: 0.0045526
# MS   beta: 0.0045682
#
# Init sigma: 0.3415975
# Ora  sigma: 0.2037484
# OS   sigma: 0.2230672
# TS   sigma: 0.2230672
# MS   sigma: 0.2230672
# True Labels 0    1036
# 1     964
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1153150
# RMSE(beta): 0.0563014
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1153150
# RMSE(beta): 0.0563014
# ######## [Step 2] ########
# norm(gradient): 0.1813168
# RMSE(beta): 0.0385643
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1153150
# RMSE(beta): 0.0563014
# ######## [Step 2] ########
# norm(gradient): 0.1813168
# RMSE(beta): 0.0385643
# ######## [Step 3] ########
# norm(gradient): 0.1455225
# RMSE(beta): 0.0389807
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.5055990
# RMSE(beta): 0.0487880
# ######## [Step 2] ########
# norm(gradient): 0.0123929
# RMSE(beta): 0.0504520
# ######## [Step 3] ########
# norm(gradient): 0.0000307
# RMSE(beta): 0.0504566
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1391944
# RMSE(sigma): 1.6316381
# ######## [Step 2] ########
# norm(sigma): 0.0389647
# RMSE(sigma): 1.3767319
# ######## [Step 3] ########
# norm(sigma): 0.0074462
# RMSE(sigma): 1.3395956
# ######## [Step 4] ########
# norm(sigma): 0.0006643
# RMSE(sigma): 1.3356630
# ######## [Step 5] ########
# norm(sigma): 0.0000094
# RMSE(sigma): 1.3355915
#
# Init beta: 0.0079371
# Ora  beta: 0.0087741
# OS   beta: 0.0125894
# TS   beta: 0.0086232
# MS   beta: 0.0087163
#
# Init sigma: 0.3094582
# Ora  sigma: 0.1574010
# OS   sigma: 0.1913001
# TS   sigma: 0.1913001
# MS   sigma: 0.1913001
# True Labels 1    1015
# 0     985
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4593313
# RMSE(beta): 0.0391897
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4593313
# RMSE(beta): 0.0391897
# ######## [Step 2] ########
# norm(gradient): 0.3526209
# RMSE(beta): 0.0398650
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4593313
# RMSE(beta): 0.0391897
# ######## [Step 2] ########
# norm(gradient): 0.3526209
# RMSE(beta): 0.0398650
# ######## [Step 3] ########
# norm(gradient): 0.2402642
# RMSE(beta): 0.0397343
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8581758
# RMSE(beta): 0.0468266
# ######## [Step 2] ########
# norm(gradient): 0.0215346
# RMSE(beta): 0.0479186
# ######## [Step 3] ########
# norm(gradient): 0.0000736
# RMSE(beta): 0.0479232
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0479232
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1317208
# RMSE(sigma): 1.8111422
# ######## [Step 2] ########
# norm(sigma): 0.0335402
# RMSE(sigma): 1.6027770
# ######## [Step 3] ########
# norm(sigma): 0.0054056
# RMSE(sigma): 1.6487833
# ######## [Step 4] ########
# norm(sigma): 0.0005374
# RMSE(sigma): 1.6619623
# ######## [Step 5] ########
# norm(sigma): 0.0000188
# RMSE(sigma): 1.6625284
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.6625297
#
# Init beta: 0.0126722
# Ora  beta: 0.0094468
# OS   beta: 0.0087631
# TS   beta: 0.0089141
# MS   beta: 0.0088849
#
# Init sigma: 0.3497987
# Ora  sigma: 0.1959310
# OS   sigma: 0.2145699
# TS   sigma: 0.2145699
# MS   sigma: 0.2145699
# True Labels 1    1009
# 0     991
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2314532
# RMSE(beta): 0.0321892
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2314532
# RMSE(beta): 0.0321892
# ######## [Step 2] ########
# norm(gradient): 0.2926717
# RMSE(beta): 0.0326146
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2314532
# RMSE(beta): 0.0321892
# ######## [Step 2] ########
# norm(gradient): 0.2926717
# RMSE(beta): 0.0326146
# ######## [Step 3] ########
# norm(gradient): 0.1854289
# RMSE(beta): 0.0325708
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7660448
# RMSE(beta): 0.0314703
# ######## [Step 2] ########
# norm(gradient): 0.0124934
# RMSE(beta): 0.0319395
# ######## [Step 3] ########
# norm(gradient): 0.0000257
# RMSE(beta): 0.0319407
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1181373
# RMSE(sigma): 1.6913452
# ######## [Step 2] ########
# norm(sigma): 0.0293649
# RMSE(sigma): 1.6414964
# ######## [Step 3] ########
# norm(sigma): 0.0040061
# RMSE(sigma): 1.6781411
# ######## [Step 4] ########
# norm(sigma): 0.0002133
# RMSE(sigma): 1.6818427
# ######## [Step 5] ########
# norm(sigma): 0.0000015
# RMSE(sigma): 1.6818672
#
# Init beta: 0.0088725
# Ora  beta: 0.0068916
# OS   beta: 0.0071977
# TS   beta: 0.0072928
# MS   beta: 0.0072831
#
# Init sigma: 0.2955254
# Ora  sigma: 0.1982099
# OS   sigma: 0.2000235
# TS   sigma: 0.2000235
# MS   sigma: 0.2000235
# True Labels 0    1001
# 1     999
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4613188
# RMSE(beta): 0.0419524
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4613188
# RMSE(beta): 0.0419524
# ######## [Step 2] ########
# norm(gradient): 0.3396695
# RMSE(beta): 0.0349026
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4613188
# RMSE(beta): 0.0419524
# ######## [Step 2] ########
# norm(gradient): 0.3396695
# RMSE(beta): 0.0349026
# ######## [Step 3] ########
# norm(gradient): 0.2379701
# RMSE(beta): 0.0350292
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8015195
# RMSE(beta): 0.0391984
# ######## [Step 2] ########
# norm(gradient): 0.0418189
# RMSE(beta): 0.0378239
# ######## [Step 3] ########
# norm(gradient): 0.0001987
# RMSE(beta): 0.0378177
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0378177
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1408483
# RMSE(sigma): 2.0539999
# ######## [Step 2] ########
# norm(sigma): 0.0384154
# RMSE(sigma): 1.8462501
# ######## [Step 3] ########
# norm(sigma): 0.0071513
# RMSE(sigma): 1.8349305
# ######## [Step 4] ########
# norm(sigma): 0.0006579
# RMSE(sigma): 1.8365313
# ######## [Step 5] ########
# norm(sigma): 0.0000107
# RMSE(sigma): 1.8366043
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.8366043
#
# Init beta: 0.0094519
# Ora  beta: 0.0082947
# OS   beta: 0.0093809
# TS   beta: 0.0078044
# MS   beta: 0.0078328
#
# Init sigma: 0.3541122
# Ora  sigma: 0.2164459
# OS   sigma: 0.2422286
# TS   sigma: 0.2422286
# MS   sigma: 0.2422286
# True Labels 0    1066
# 1     934
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2489259
# RMSE(beta): 0.0349668
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2489259
# RMSE(beta): 0.0349668
# ######## [Step 2] ########
# norm(gradient): 0.2648170
# RMSE(beta): 0.0307435
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2489259
# RMSE(beta): 0.0349668
# ######## [Step 2] ########
# norm(gradient): 0.2648170
# RMSE(beta): 0.0307435
# ######## [Step 3] ########
# norm(gradient): 0.1550395
# RMSE(beta): 0.0306100
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7219064
# RMSE(beta): 0.0338671
# ######## [Step 2] ########
# norm(gradient): 0.0173103
# RMSE(beta): 0.0352474
# ######## [Step 3] ########
# norm(gradient): 0.0000503
# RMSE(beta): 0.0352522
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1457245
# RMSE(sigma): 1.8854832
# ######## [Step 2] ########
# norm(sigma): 0.0365517
# RMSE(sigma): 1.7439718
# ######## [Step 3] ########
# norm(sigma): 0.0049523
# RMSE(sigma): 1.7159808
# ######## [Step 4] ########
# norm(sigma): 0.0002639
# RMSE(sigma): 1.7130586
# ######## [Step 5] ########
# norm(sigma): 0.0000024
# RMSE(sigma): 1.7130332
#
# Init beta: 0.0165271
# Ora  beta: 0.0068373
# OS   beta: 0.0078188
# TS   beta: 0.0068745
# MS   beta: 0.0068446
#
# Init sigma: 0.3120842
# Ora  sigma: 0.2018829
# OS   sigma: 0.2216089
# TS   sigma: 0.2216089
# MS   sigma: 0.2216089
# True Labels 1    1120
# 0     880
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3335596
# RMSE(beta): 0.0343484
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3335596
# RMSE(beta): 0.0343484
# ######## [Step 2] ########
# norm(gradient): 0.3397312
# RMSE(beta): 0.0392697
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3335596
# RMSE(beta): 0.0343484
# ######## [Step 2] ########
# norm(gradient): 0.3397312
# RMSE(beta): 0.0392697
# ######## [Step 3] ########
# norm(gradient): 0.2286792
# RMSE(beta): 0.0390012
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7659647
# RMSE(beta): 0.0473671
# ######## [Step 2] ########
# norm(gradient): 0.0191487
# RMSE(beta): 0.0475382
# ######## [Step 3] ########
# norm(gradient): 0.0000522
# RMSE(beta): 0.0475387
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1262070
# RMSE(sigma): 1.7911091
# ######## [Step 2] ########
# norm(sigma): 0.0327050
# RMSE(sigma): 1.5767350
# ######## [Step 3] ########
# norm(sigma): 0.0049995
# RMSE(sigma): 1.5924734
# ######## [Step 4] ########
# norm(sigma): 0.0003778
# RMSE(sigma): 1.5978936
# ######## [Step 5] ########
# norm(sigma): 0.0000069
# RMSE(sigma): 1.5979785
#
# Init beta: 0.0126613
# Ora  beta: 0.0106326
# OS   beta: 0.0076805
# TS   beta: 0.0087810
# MS   beta: 0.0087209
#
# Init sigma: 0.3233149
# Ora  sigma: 0.1883236
# OS   sigma: 0.2055997
# TS   sigma: 0.2055997
# MS   sigma: 0.2055997
# True Labels 0    1049
# 1     951
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1486690
# RMSE(beta): 0.0445122
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1486690
# RMSE(beta): 0.0445122
# ######## [Step 2] ########
# norm(gradient): 0.3066582
# RMSE(beta): 0.0435717
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1486690
# RMSE(beta): 0.0445122
# ######## [Step 2] ########
# norm(gradient): 0.3066582
# RMSE(beta): 0.0435717
# ######## [Step 3] ########
# norm(gradient): 0.2070021
# RMSE(beta): 0.0436820
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6393726
# RMSE(beta): 0.0438371
# ######## [Step 2] ########
# norm(gradient): 0.0143956
# RMSE(beta): 0.0434853
# ######## [Step 3] ########
# norm(gradient): 0.0000246
# RMSE(beta): 0.0434844
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1372820
# RMSE(sigma): 1.4939254
# ######## [Step 2] ########
# norm(sigma): 0.0375372
# RMSE(sigma): 1.5671624
# ######## [Step 3] ########
# norm(sigma): 0.0067852
# RMSE(sigma): 1.6389598
# ######## [Step 4] ########
# norm(sigma): 0.0005449
# RMSE(sigma): 1.6444908
# ######## [Step 5] ########
# norm(sigma): 0.0000060
# RMSE(sigma): 1.6445377
#
# Init beta: 0.0123643
# Ora  beta: 0.0093970
# OS   beta: 0.0099532
# TS   beta: 0.0097429
# MS   beta: 0.0097676
#
# Init sigma: 0.2793357
# Ora  sigma: 0.1938106
# OS   sigma: 0.1767873
# TS   sigma: 0.1767873
# MS   sigma: 0.1767873
# True Labels 0    1076
# 1     924
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.0869826
# RMSE(beta): 0.0239628
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.0869826
# RMSE(beta): 0.0239628
# ######## [Step 2] ########
# norm(gradient): 0.2172068
# RMSE(beta): 0.0201835
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.0869826
# RMSE(beta): 0.0239628
# ######## [Step 2] ########
# norm(gradient): 0.2172068
# RMSE(beta): 0.0201835
# ######## [Step 3] ########
# norm(gradient): 0.1711343
# RMSE(beta): 0.0201183
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6084487
# RMSE(beta): 0.0348248
# ######## [Step 2] ########
# norm(gradient): 0.0183111
# RMSE(beta): 0.0366993
# ######## [Step 3] ########
# norm(gradient): 0.0000475
# RMSE(beta): 0.0367048
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1218408
# RMSE(sigma): 2.0158855
# ######## [Step 2] ########
# norm(sigma): 0.0320419
# RMSE(sigma): 1.8608015
# ######## [Step 3] ########
# norm(sigma): 0.0058645
# RMSE(sigma): 1.8581324
# ######## [Step 4] ########
# norm(sigma): 0.0006942
# RMSE(sigma): 1.8577289
# ######## [Step 5] ########
# norm(sigma): 0.0000221
# RMSE(sigma): 1.8576888
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.8576888
#
# Init beta: 0.0119405
# Ora  beta: 0.0043406
# OS   beta: 0.0053583
# TS   beta: 0.0045132
# MS   beta: 0.0044986
#
# Init sigma: 0.3367353
# Ora  sigma: 0.2189307
# OS   sigma: 0.2354489
# TS   sigma: 0.2354489
# MS   sigma: 0.2354489
# True Labels 1    1097
# 0     903
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4249441
# RMSE(beta): 0.0231734
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4249441
# RMSE(beta): 0.0231734
# ######## [Step 2] ########
# norm(gradient): 0.3021870
# RMSE(beta): 0.0303697
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.4249441
# RMSE(beta): 0.0231734
# ######## [Step 2] ########
# norm(gradient): 0.3021870
# RMSE(beta): 0.0303697
# ######## [Step 3] ########
# norm(gradient): 0.1773019
# RMSE(beta): 0.0299961
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9090621
# RMSE(beta): 0.0323138
# ######## [Step 2] ########
# norm(gradient): 0.0234278
# RMSE(beta): 0.0329974
# ######## [Step 3] ########
# norm(gradient): 0.0000778
# RMSE(beta): 0.0330002
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0330002
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1297571
# RMSE(sigma): 1.9818982
# ######## [Step 2] ########
# norm(sigma): 0.0343541
# RMSE(sigma): 1.7338018
# ######## [Step 3] ########
# norm(sigma): 0.0059433
# RMSE(sigma): 1.6926407
# ######## [Step 4] ########
# norm(sigma): 0.0006031
# RMSE(sigma): 1.6878086
# ######## [Step 5] ########
# norm(sigma): 0.0000185
# RMSE(sigma): 1.6876692
# ######## [Step 6] ########
# norm(sigma): 0.0000000
# RMSE(sigma): 1.6876690
#
# Init beta: 0.0151804
# Ora  beta: 0.0072277
# OS   beta: 0.0051817
# TS   beta: 0.0067909
# MS   beta: 0.0067073
#
# Init sigma: 0.3405332
# Ora  sigma: 0.1988937
# OS   sigma: 0.2294069
# TS   sigma: 0.2294069
# MS   sigma: 0.2294069
# True Labels 0    1006
# 1     994
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.6781783
# RMSE(beta): 0.0234233
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.6781783
# RMSE(beta): 0.0234233
# ######## [Step 2] ########
# norm(gradient): 0.4112622
# RMSE(beta): 0.0265782
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.6781783
# RMSE(beta): 0.0234233
# ######## [Step 2] ########
# norm(gradient): 0.4112622
# RMSE(beta): 0.0265782
# ######## [Step 3] ########
# norm(gradient): 0.1824860
# RMSE(beta): 0.0263095
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2472455
# RMSE(beta): 0.0250679
# ######## [Step 2] ########
# norm(gradient): 0.0350420
# RMSE(beta): 0.0278613
# ######## [Step 3] ########
# norm(gradient): 0.0001825
# RMSE(beta): 0.0278805
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0278805
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1262944
# RMSE(sigma): 1.8228726
# ######## [Step 2] ########
# norm(sigma): 0.0308179
# RMSE(sigma): 1.6358161
# ######## [Step 3] ########
# norm(sigma): 0.0039492
# RMSE(sigma): 1.6354293
# ######## [Step 4] ########
# norm(sigma): 0.0001342
# RMSE(sigma): 1.6359669
# ######## [Step 5] ########
# norm(sigma): 0.0000003
# RMSE(sigma): 1.6359691
#
# Init beta: 0.0119555
# Ora  beta: 0.0049638
# OS   beta: 0.0052376
# TS   beta: 0.0059431
# MS   beta: 0.0058830
#
# Init sigma: 0.3345794
# Ora  sigma: 0.1928008
# OS   sigma: 0.2164988
# TS   sigma: 0.2164988
# MS   sigma: 0.2164988
# True Labels 0    1029
# 1     971
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3633480
# RMSE(beta): 0.0599890
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3633480
# RMSE(beta): 0.0599890
# ######## [Step 2] ########
# norm(gradient): 0.3133952
# RMSE(beta): 0.0527824
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3633480
# RMSE(beta): 0.0599890
# ######## [Step 2] ########
# norm(gradient): 0.3133952
# RMSE(beta): 0.0527824
# ######## [Step 3] ########
# norm(gradient): 0.1883183
# RMSE(beta): 0.0531631
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7994808
# RMSE(beta): 0.0537073
# ######## [Step 2] ########
# norm(gradient): 0.0179149
# RMSE(beta): 0.0540574
# ######## [Step 3] ########
# norm(gradient): 0.0000504
# RMSE(beta): 0.0540584
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1223626
# RMSE(sigma): 1.5975583
# ######## [Step 2] ########
# norm(sigma): 0.0342576
# RMSE(sigma): 1.5524129
# ######## [Step 3] ########
# norm(sigma): 0.0053574
# RMSE(sigma): 1.5873479
# ######## [Step 4] ########
# norm(sigma): 0.0003681
# RMSE(sigma): 1.5901772
# ######## [Step 5] ########
# norm(sigma): 0.0000059
# RMSE(sigma): 1.5901950
#
# Init beta: 0.0081878
# Ora  beta: 0.0120915
# OS   beta: 0.0134140
# TS   beta: 0.0118025
# MS   beta: 0.0118876
#
# Init sigma: 0.2903065
# Ora  sigma: 0.1874063
# OS   sigma: 0.1876811
# TS   sigma: 0.1876811
# MS   sigma: 0.1876811
# True Labels 0    1010
# 1     990
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3773218
# RMSE(beta): 0.0716584
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3773218
# RMSE(beta): 0.0716584
# ######## [Step 2] ########
# norm(gradient): 0.3622430
# RMSE(beta): 0.0602701
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.3773218
# RMSE(beta): 0.0716584
# ######## [Step 2] ########
# norm(gradient): 0.3622430
# RMSE(beta): 0.0602701
# ######## [Step 3] ########
# norm(gradient): 0.2451173
# RMSE(beta): 0.0607409
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7273681
# RMSE(beta): 0.0616136
# ######## [Step 2] ########
# norm(gradient): 0.0291771
# RMSE(beta): 0.0598703
# ######## [Step 3] ########
# norm(gradient): 0.0001188
# RMSE(beta): 0.0598636
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0598636
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1474859
# RMSE(sigma): 1.6446467
# ######## [Step 2] ########
# norm(sigma): 0.0375063
# RMSE(sigma): 1.6150279
# ######## [Step 3] ########
# norm(sigma): 0.0051818
# RMSE(sigma): 1.6670198
# ######## [Step 4] ########
# norm(sigma): 0.0002403
# RMSE(sigma): 1.6701069
# ######## [Step 5] ########
# norm(sigma): 0.0000015
# RMSE(sigma): 1.6701122
#
# Init beta: 0.0095454
# Ora  beta: 0.0129345
# OS   beta: 0.0160233
# TS   beta: 0.0134768
# MS   beta: 0.0135821
#
# Init sigma: 0.3095874
# Ora  sigma: 0.1968246
# OS   sigma: 0.1956175
# TS   sigma: 0.1956175
# MS   sigma: 0.1956175
# True Labels 1    1015
# 0     985
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2966807
# RMSE(beta): 0.0279064
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2966807
# RMSE(beta): 0.0279064
# ######## [Step 2] ########
# norm(gradient): 0.3630217
# RMSE(beta): 0.0285226
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.2966807
# RMSE(beta): 0.0279064
# ######## [Step 2] ########
# norm(gradient): 0.3630217
# RMSE(beta): 0.0285226
# ######## [Step 3] ########
# norm(gradient): 0.2733649
# RMSE(beta): 0.0283652
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7503360
# RMSE(beta): 0.0334294
# ######## [Step 2] ########
# norm(gradient): 0.0183804
# RMSE(beta): 0.0351398
# ######## [Step 3] ########
# norm(gradient): 0.0000592
# RMSE(beta): 0.0351461
# ######## [Step 4] ########
# norm(gradient): 0.0000000
# RMSE(beta): 0.0351461
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.1591468
# RMSE(sigma): 1.8177559
# ######## [Step 2] ########
# norm(sigma): 0.0450621
# RMSE(sigma): 1.3750654
# ######## [Step 3] ########
# norm(sigma): 0.0087401
# RMSE(sigma): 1.2942495
# ######## [Step 4] ########
# norm(sigma): 0.0008929
# RMSE(sigma): 1.2837894
# ######## [Step 5] ########
# norm(sigma): 0.0000228
# ...
# MS   beta: 0.0011981
#
# Init sigma: 0.1033507
# Ora  sigma: 0.0848230
# OS   sigma: 0.0847051
# TS   sigma: 0.0847051
# MS   sigma: 0.0847051
# True Labels 0    5193
# 1    4807
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9469321
# RMSE(beta): 0.0050512
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9469321
# RMSE(beta): 0.0050512
# ######## [Step 2] ########
# norm(gradient): 0.0550423
# RMSE(beta): 0.0049980
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9469321
# RMSE(beta): 0.0050512
# ######## [Step 2] ########
# norm(gradient): 0.0550423
# RMSE(beta): 0.0049980
# ######## [Step 3] ########
# norm(gradient): 0.0431932
# RMSE(beta): 0.0049980
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7111651
# RMSE(beta): 0.0048634
# ######## [Step 2] ########
# norm(gradient): 0.0019532
# RMSE(beta): 0.0048711
# ######## [Step 3] ########
# norm(gradient): 0.0000002
# RMSE(beta): 0.0048711
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0397258
# RMSE(sigma): 1.4881441
# ######## [Step 2] ########
# norm(sigma): 0.0036411
# RMSE(sigma): 1.4933458
# ######## [Step 3] ########
# norm(sigma): 0.0000925
# RMSE(sigma): 1.4936448
# ######## [Step 4] ########
# norm(sigma): 0.0000002
# RMSE(sigma): 1.4936448
#
# Init beta: 0.0015490
# Ora  beta: 0.0010882
# OS   beta: 0.0011295
# TS   beta: 0.0011176
# MS   beta: 0.0011176
#
# Init sigma: 0.1051557
# Ora  sigma: 0.0872597
# OS   sigma: 0.0870354
# TS   sigma: 0.0870354
# MS   sigma: 0.0870354
# True Labels 0    5022
# 1    4978
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9493335
# RMSE(beta): 0.0045099
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9493335
# RMSE(beta): 0.0045099
# ######## [Step 2] ########
# norm(gradient): 0.0521682
# RMSE(beta): 0.0044071
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9493335
# RMSE(beta): 0.0045099
# ######## [Step 2] ########
# norm(gradient): 0.0521682
# RMSE(beta): 0.0044071
# ######## [Step 3] ########
# norm(gradient): 0.0398250
# RMSE(beta): 0.0044072
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6686657
# RMSE(beta): 0.0044308
# ######## [Step 2] ########
# norm(gradient): 0.0022356
# RMSE(beta): 0.0044418
# ######## [Step 3] ########
# norm(gradient): 0.0000003
# RMSE(beta): 0.0044418
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0429762
# RMSE(sigma): 1.4471541
# ######## [Step 2] ########
# norm(sigma): 0.0038544
# RMSE(sigma): 1.4453634
# ######## [Step 3] ########
# norm(sigma): 0.0000939
# RMSE(sigma): 1.4455305
# ######## [Step 4] ########
# norm(sigma): 0.0000003
# RMSE(sigma): 1.4455309
#
# Init beta: 0.0019741
# Ora  beta: 0.0009864
# OS   beta: 0.0010084
# TS   beta: 0.0009855
# MS   beta: 0.0009855
#
# Init sigma: 0.1049617
# Ora  sigma: 0.0844488
# OS   sigma: 0.0845347
# TS   sigma: 0.0845347
# MS   sigma: 0.0845347
# True Labels 1    5153
# 0    4847
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8450810
# RMSE(beta): 0.0068297
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8450810
# RMSE(beta): 0.0068297
# ######## [Step 2] ########
# norm(gradient): 0.0528395
# RMSE(beta): 0.0067377
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8450810
# RMSE(beta): 0.0068297
# ######## [Step 2] ########
# norm(gradient): 0.0528395
# RMSE(beta): 0.0067377
# ######## [Step 3] ########
# norm(gradient): 0.0492605
# RMSE(beta): 0.0067379
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6499732
# RMSE(beta): 0.0122763
# ######## [Step 2] ########
# norm(gradient): 0.0069116
# RMSE(beta): 0.0121018
# ######## [Step 3] ########
# norm(gradient): 0.0000015
# RMSE(beta): 0.0121018
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0405701
# RMSE(sigma): 1.5354016
# ######## [Step 2] ########
# norm(sigma): 0.0038591
# RMSE(sigma): 1.5451031
# ######## [Step 3] ########
# norm(sigma): 0.0001255
# RMSE(sigma): 1.5457822
# ######## [Step 4] ########
# norm(sigma): 0.0000005
# RMSE(sigma): 1.5457845
#
# Init beta: 0.0017027
# Ora  beta: 0.0015404
# OS   beta: 0.0015272
# TS   beta: 0.0015066
# MS   beta: 0.0015066
#
# Init sigma: 0.1044136
# Ora  sigma: 0.0903057
# OS   sigma: 0.0895937
# TS   sigma: 0.0895937
# MS   sigma: 0.0895937
# True Labels 1    5188
# 0    4812
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9420264
# RMSE(beta): 0.0056779
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9420264
# RMSE(beta): 0.0056779
# ######## [Step 2] ########
# norm(gradient): 0.0633605
# RMSE(beta): 0.0057207
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9420264
# RMSE(beta): 0.0056779
# ######## [Step 2] ########
# norm(gradient): 0.0633605
# RMSE(beta): 0.0057207
# ######## [Step 3] ########
# norm(gradient): 0.0589831
# RMSE(beta): 0.0057206
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7218944
# RMSE(beta): 0.0055740
# ######## [Step 2] ########
# norm(gradient): 0.0024860
# RMSE(beta): 0.0055996
# ######## [Step 3] ########
# norm(gradient): 0.0000004
# RMSE(beta): 0.0055996
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0399781
# RMSE(sigma): 1.4285973
# ######## [Step 2] ########
# norm(sigma): 0.0037394
# RMSE(sigma): 1.4230832
# ######## [Step 3] ########
# norm(sigma): 0.0001498
# RMSE(sigma): 1.4235639
# ######## [Step 4] ########
# norm(sigma): 0.0000012
# RMSE(sigma): 1.4235700
#
# Init beta: 0.0025154
# Ora  beta: 0.0012395
# OS   beta: 0.0012696
# TS   beta: 0.0012792
# MS   beta: 0.0012792
#
# Init sigma: 0.1077213
# Ora  sigma: 0.0831658
# OS   sigma: 0.0836376
# TS   sigma: 0.0836376
# MS   sigma: 0.0836376
# True Labels 0    5102
# 1    4898
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9089368
# RMSE(beta): 0.0092651
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9089368
# RMSE(beta): 0.0092651
# ######## [Step 2] ########
# norm(gradient): 0.0441435
# RMSE(beta): 0.0105276
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9089368
# RMSE(beta): 0.0092651
# ######## [Step 2] ########
# norm(gradient): 0.0441435
# RMSE(beta): 0.0105276
# ######## [Step 3] ########
# norm(gradient): 0.0348507
# RMSE(beta): 0.0105252
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6562602
# RMSE(beta): 0.0106080
# ######## [Step 2] ########
# norm(gradient): 0.0021906
# RMSE(beta): 0.0106118
# ######## [Step 3] ########
# norm(gradient): 0.0000002
# RMSE(beta): 0.0106118
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0413451
# RMSE(sigma): 1.5094764
# ######## [Step 2] ########
# norm(sigma): 0.0041179
# RMSE(sigma): 1.4993935
# ######## [Step 3] ########
# norm(sigma): 0.0001245
# RMSE(sigma): 1.4990327
# ######## [Step 4] ########
# norm(sigma): 0.0000005
# RMSE(sigma): 1.4990303
#
# Init beta: 0.0039219
# Ora  beta: 0.0023583
# OS   beta: 0.0020717
# TS   beta: 0.0023540
# MS   beta: 0.0023535
#
# Init sigma: 0.1093920
# Ora  sigma: 0.0875743
# OS   sigma: 0.0880547
# TS   sigma: 0.0880547
# MS   sigma: 0.0880547
# True Labels 1    5049
# 0    4951
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9508491
# RMSE(beta): 0.0059981
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9508491
# RMSE(beta): 0.0059981
# ######## [Step 2] ########
# norm(gradient): 0.0449343
# RMSE(beta): 0.0061991
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9508491
# RMSE(beta): 0.0059981
# ######## [Step 2] ########
# norm(gradient): 0.0449343
# RMSE(beta): 0.0061991
# ######## [Step 3] ########
# norm(gradient): 0.0332521
# RMSE(beta): 0.0061986
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.7208367
# RMSE(beta): 0.0065481
# ######## [Step 2] ########
# norm(gradient): 0.0025280
# RMSE(beta): 0.0065716
# ######## [Step 3] ########
# norm(gradient): 0.0000003
# RMSE(beta): 0.0065716
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0380744
# RMSE(sigma): 1.3421312
# ######## [Step 2] ########
# norm(sigma): 0.0030666
# RMSE(sigma): 1.3576060
# ######## [Step 3] ########
# norm(sigma): 0.0000497
# RMSE(sigma): 1.3580588
# ######## [Step 4] ########
# norm(sigma): 0.0000001
# RMSE(sigma): 1.3580594
#
# Init beta: 0.0027987
# Ora  beta: 0.0014259
# OS   beta: 0.0013412
# TS   beta: 0.0013862
# MS   beta: 0.0013860
#
# Init sigma: 0.0907747
# Ora  sigma: 0.0793387
# OS   sigma: 0.0784213
# TS   sigma: 0.0784213
# MS   sigma: 0.0784213
# True Labels 1    5495
# 0    4505
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1223764
# RMSE(beta): 0.0044796
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1223764
# RMSE(beta): 0.0044796
# ######## [Step 2] ########
# norm(gradient): 0.0562908
# RMSE(beta): 0.0058255
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1223764
# RMSE(beta): 0.0044796
# ######## [Step 2] ########
# norm(gradient): 0.0562908
# RMSE(beta): 0.0058255
# ######## [Step 3] ########
# norm(gradient): 0.0274506
# RMSE(beta): 0.0058243
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9316110
# RMSE(beta): 0.0058077
# ######## [Step 2] ########
# norm(gradient): 0.0049124
# RMSE(beta): 0.0057978
# ######## [Step 3] ########
# norm(gradient): 0.0000010
# RMSE(beta): 0.0057978
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0430867
# RMSE(sigma): 1.3583169
# ######## [Step 2] ########
# norm(sigma): 0.0050872
# RMSE(sigma): 1.3597500
# ######## [Step 3] ########
# norm(sigma): 0.0003166
# RMSE(sigma): 1.3629825
# ######## [Step 4] ########
# norm(sigma): 0.0000036
# RMSE(sigma): 1.3630236
#
# Init beta: 0.0031758
# Ora  beta: 0.0012844
# OS   beta: 0.0010017
# TS   beta: 0.0013026
# MS   beta: 0.0013024
#
# Init sigma: 0.1100755
# Ora  sigma: 0.0796287
# OS   sigma: 0.0792759
# TS   sigma: 0.0792759
# MS   sigma: 0.0792759
# True Labels 0    5068
# 1    4932
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9127867
# RMSE(beta): 0.0047668
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9127867
# RMSE(beta): 0.0047668
# ######## [Step 2] ########
# norm(gradient): 0.0653504
# RMSE(beta): 0.0045630
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9127867
# RMSE(beta): 0.0047668
# ######## [Step 2] ########
# norm(gradient): 0.0653504
# RMSE(beta): 0.0045630
# ######## [Step 3] ########
# norm(gradient): 0.0577440
# RMSE(beta): 0.0045637
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6813951
# RMSE(beta): 0.0044818
# ######## [Step 2] ########
# norm(gradient): 0.0021332
# RMSE(beta): 0.0044509
# ######## [Step 3] ########
# norm(gradient): 0.0000003
# RMSE(beta): 0.0044509
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0472479
# RMSE(sigma): 1.4500228
# ######## [Step 2] ########
# norm(sigma): 0.0052380
# RMSE(sigma): 1.4437705
# ######## [Step 3] ########
# norm(sigma): 0.0003662
# RMSE(sigma): 1.4416544
# ######## [Step 4] ########
# norm(sigma): 0.0000074
# RMSE(sigma): 1.4416005
#
# Init beta: 0.0027760
# Ora  beta: 0.0009725
# OS   beta: 0.0010659
# TS   beta: 0.0010203
# MS   beta: 0.0010205
#
# Init sigma: 0.1025726
# Ora  sigma: 0.0842192
# OS   sigma: 0.0846845
# TS   sigma: 0.0846845
# MS   sigma: 0.0846845
# True Labels 0    5314
# 1    4686
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1144134
# RMSE(beta): 0.0073199
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1144134
# RMSE(beta): 0.0073199
# ######## [Step 2] ########
# norm(gradient): 0.0482500
# RMSE(beta): 0.0069589
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 1.1144134
# RMSE(beta): 0.0073199
# ######## [Step 2] ########
# norm(gradient): 0.0482500
# RMSE(beta): 0.0069589
# ######## [Step 3] ########
# norm(gradient): 0.0280796
# RMSE(beta): 0.0069592
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8351860
# RMSE(beta): 0.0088246
# ######## [Step 2] ########
# norm(gradient): 0.0036823
# RMSE(beta): 0.0089438
# ######## [Step 3] ########
# norm(gradient): 0.0000007
# RMSE(beta): 0.0089438
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0434893
# RMSE(sigma): 1.5119813
# ######## [Step 2] ########
# norm(sigma): 0.0044727
# RMSE(sigma): 1.5004585
# ######## [Step 3] ########
# norm(sigma): 0.0002010
# RMSE(sigma): 1.5006593
# ######## [Step 4] ########
# norm(sigma): 0.0000014
# RMSE(sigma): 1.5006606
#
# Init beta: 0.0024010
# Ora  beta: 0.0015398
# OS   beta: 0.0016368
# TS   beta: 0.0015561
# MS   beta: 0.0015561
#
# Init sigma: 0.1121567
# Ora  sigma: 0.0876695
# OS   sigma: 0.0881895
# TS   sigma: 0.0881895
# MS   sigma: 0.0881895
# True Labels 1    5187
# 0    4813
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8556527
# RMSE(beta): 0.0064971
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8556527
# RMSE(beta): 0.0064971
# ######## [Step 2] ########
# norm(gradient): 0.0525294
# RMSE(beta): 0.0072381
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.8556527
# RMSE(beta): 0.0064971
# ######## [Step 2] ########
# norm(gradient): 0.0525294
# RMSE(beta): 0.0072381
# ######## [Step 3] ########
# norm(gradient): 0.0468095
# RMSE(beta): 0.0072360
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6635365
# RMSE(beta): 0.0072978
# ######## [Step 2] ########
# norm(gradient): 0.0017179
# RMSE(beta): 0.0073125
# ######## [Step 3] ########
# norm(gradient): 0.0000002
# RMSE(beta): 0.0073125
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0426646
# RMSE(sigma): 1.4406729
# ######## [Step 2] ########
# norm(sigma): 0.0042529
# RMSE(sigma): 1.4159721
# ######## [Step 3] ########
# norm(sigma): 0.0001131
# RMSE(sigma): 1.4152409
# ######## [Step 4] ########
# norm(sigma): 0.0000002
# RMSE(sigma): 1.4152388
#
# Init beta: 0.0023666
# Ora  beta: 0.0016279
# OS   beta: 0.0014528
# TS   beta: 0.0016185
# MS   beta: 0.0016180
#
# Init sigma: 0.1094062
# Ora  sigma: 0.0826791
# OS   sigma: 0.0841583
# TS   sigma: 0.0841583
# MS   sigma: 0.0841583
# True Labels 1    5321
# 0    4679
# dtype: int64
#
#
# ########## Initial Estimator ##########
#
# ########## OS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9189283
# RMSE(beta): 0.0065360
#
# ########## TS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9189283
# RMSE(beta): 0.0065360
# ######## [Step 2] ########
# norm(gradient): 0.0628142
# RMSE(beta): 0.0054577
#
# ########## MS Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.9189283
# RMSE(beta): 0.0065360
# ######## [Step 2] ########
# norm(gradient): 0.0628142
# RMSE(beta): 0.0054577
# ######## [Step 3] ########
# norm(gradient): 0.0603123
# RMSE(beta): 0.0054604
#
# ########## ORACLE_beta Estimator ##########
# ######## [Step 1] ########
# norm(gradient): 0.6317900
# RMSE(beta): 0.0056335
# ######## [Step 2] ########
# norm(gradient): 0.0015997
# RMSE(beta): 0.0056651
# ######## [Step 3] ########
# norm(gradient): 0.0000001
# RMSE(beta): 0.0056651
#
# ########## ORACLE_sigma Estimator ##########
# ######## [Step 1] ########
# norm(sigma): 0.0483565
# RMSE(sigma): 1.5549392
# ######## [Step 2] ########
# norm(sigma): 0.0061823
# RMSE(sigma): 1.5546599
#
# ########## Initial Estimator ##########
