# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.discrete.discrete_model import Probit
from sklearn.model_selection import train_test_split

# %%
np.random.seed(0)

N = 1000000
p = 10 # dimension of features

# %% [markdown]
# - data:

# %%
X = np.random.randn(N, p)
X[:, 0] = 1                              # set to be constants
beta0 = np.ones(p)
Y_true = (X.dot(beta0) > 0).astype(int)
Y_true.mean()
# Out:
# 0.63099

# %%
sigma0_list = [1, 10, 0.02]
M = len(sigma0_list)  # number of annotators

# %% [markdown]
# ## First-Round Sampling

# %%
X1, X2, Y1_true, Y2_true = train_test_split(X, Y_true, random_state=0, test_size=0.999)
n = X1.shape[0]; print(f"first-round size: {n}")
# Out:
# first-round size: 1000

# %% [markdown]
# ## stack $M$ annotations to create a new dataset

# %%
# X1_stack = np.concatenate([X1 / sigma for sigma in sigma0_list], axis=0)
X1_stack_list = []
Y1_stack_list = []
for m in range(M):
    sigma_0m = sigma0_list[m]
    epsilon_m = np.random.randn(n) * sigma_0m
    Y_im = (X1.dot(beta0) + epsilon_m > 0).astype(int)
    print(f"Class1 ratio: {Y_im.mean()}")
    X1_stack_list.append(X1 / sigma_0m)
    Y1_stack_list.append(Y_im)
# Out:
# Class1 ratio: 0.64
# Class1 ratio: 0.525
# Class1 ratio: 0.637

# %%
X1_stack = np.concatenate(X1_stack_list, axis=0)
Y1_stack = np.concatenate(Y1_stack_list, axis=0)
X1_stack.shape
# Out:
# (3000, 10)

# %%
model = Probit(Y1_stack, X1_stack.astype(float))
probit_model = model.fit()
print(probit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.286387
#          Iterations 14
#                           Probit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3000
# Model:                         Probit   Df Residuals:                     2990
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 09 Jun 2023   Pseudo R-squ.:                  0.5743
# Time:                        15:37:08   Log-Likelihood:                -859.16
# converged:                       True   LL-Null:                       -2018.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.0956      0.070     15.665      0.000       0.958       1.233
# x2             1.0582      0.072     14.650      0.000       0.917       1.200
# x3             1.0710      0.068     15.665      0.000       0.937       1.205
# x4             1.0554      0.071     14.930      0.000       0.917       1.194
# x5             1.0840      0.068     16.024      0.000       0.951       1.217
# x6             1.0874      0.067     16.285      0.000       0.957       1.218
# x7             1.0867      0.067     16.175      0.000       0.955       1.218
# x8             1.0814      0.073     14.766      0.000       0.938       1.225
# x9             1.0467      0.069     15.228      0.000       0.912       1.181
# x10            1.0520      0.064     16.366      0.000       0.926       1.178
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.42 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %%
print(f"sigma: {sigma0_list}")
beta_hat = probit_model.params
mse = ((beta_hat - beta0)**2).sum()
print(f"MSE: {mse: .4f}")
Y2_pred = (X2.dot(beta_hat) > 0).astype(int)
acc = (Y2_pred == Y2_true).mean()
print(f"ACC: {acc: .4f}")
# Out:
# sigma: [1, 10, 0.02]
# MSE:  0.0544
# ACC:  0.9950

# %%
sigma0_list = [1, 10, 0.02]
sigmam_list = [0.008, 0.02]
M = len(sigma0_list)  # number of annotators

repetition = 100
results = []

for seed in range(repetition):
    np.random.seed(seed)
    for sigma_m in sigmam_list: #np.arange(start=0.01, stop=0.1, step=0.01):
        sigma0_list[2] = sigma_m

        X1_stack_list = []
        Y1_stack_list = []
        for m in range(M):
            sigma_0m = sigma0_list[m]
            epsilon_m = np.random.randn(n) * sigma_0m
            Y_im = (X1.dot(beta0) + epsilon_m > 0).astype(int)
    #         print(f"Class1 ratio: {Y_im.mean()}")
            X1_stack_list.append(X1 / sigma_0m)
            Y1_stack_list.append(Y_im)
        X1_stack = np.concatenate(X1_stack_list, axis=0)
        Y1_stack = np.concatenate(Y1_stack_list, axis=0)
        model = Probit(Y1_stack, X1_stack.astype(float))
        probit_model = model.fit()
        
        beta_hat = probit_model.params
        mse = ((beta_hat - beta0)**2).sum()
        Y2_pred = (X2.dot(beta_hat) > 0).astype(int)
        acc = (Y2_pred == Y2_true).mean()
        print(f"{sigma_m}:\tMSE: {mse: .4f}\tACC: {acc: .4f}")
        
        results.append([seed, sigma_m, mse, acc])
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.311284
#          Iterations: 35
# 0.008:	MSE:  0.0307	ACC:  0.9926
# Optimization terminated successfully.
#          Current function value: 0.275536
#          Iterations 15
# 0.02:	MSE:  0.4422	ACC:  0.9942
# Optimization terminated successfully.
#          Current function value: 0.282846
#          Iterations 19
# 0.008:	MSE:  0.1109	ACC:  0.9922
# Optimization terminated successfully.
#          Current function value: 0.290179
#          Iterations 14
# 0.02:	MSE:  0.0086	ACC:  0.9936
# Optimization terminated successfully.
#          Current function value: 0.291711
#          Iterations 17
# 0.008:	MSE:  0.0038	ACC:  0.9940
# Optimization terminated successfully.
#          Current function value: 0.291507
#          Iterations 14
# 0.02:	MSE:  0.0033	ACC:  0.9966
# Optimization terminated successfully.
#          Current function value: 0.292021
#          Iterations 19
# 0.008:	MSE:  0.0114	ACC:  0.9893
# Optimization terminated successfully.
#          Current function value: 0.296544
#          Iterations 14
# 0.02:	MSE:  0.0317	ACC:  0.9970
# Optimization terminated successfully.
#          Current function value: 0.287747
#          Iterations 20
# 0.008:	MSE:  0.0259	ACC:  0.9952
# Optimization terminated successfully.
#          Current function value: 0.296495
#          Iterations 14
# 0.02:	MSE:  0.0276	ACC:  0.9961
# Optimization terminated successfully.
#          Current function value: 0.300499
#          Iterations 19
# 0.008:	MSE:  0.1157	ACC:  0.9933
# Optimization terminated successfully.
#          Current function value: 0.300728
#          Iterations 14
# 0.02:	MSE:  0.0776	ACC:  0.9943
# Optimization terminated successfully.
#          Current function value: 0.291043
#          Iterations 34
# 0.008:	MSE:  0.0084	ACC:  0.9909
# Optimization terminated successfully.
#          Current function value: 0.280122
#          Iterations 14
# 0.02:	MSE:  0.2182	ACC:  0.9973
# Optimization terminated successfully.
#          Current function value: 0.289908
#          Iterations 21
# 0.008:	MSE:  0.0034	ACC:  0.9973
# Optimization terminated successfully.
#          Current function value: 0.299131
#          Iterations 14
# 0.02:	MSE:  0.0677	ACC:  0.9938
# Optimization terminated successfully.
#          Current function value: 0.295847
#          Iterations 18
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0.008:	MSE:  0.0219	ACC:  0.9930
# Optimization terminated successfully.
#          Current function value: 0.293449
#          Iterations 14
# 0.02:	MSE:  0.0066	ACC:  0.9935
# Optimization terminated successfully.
#          Current function value: 0.292780
#          Iterations 18
# 0.008:	MSE:  0.0082	ACC:  0.9919
# Optimization terminated successfully.
#          Current function value: 0.281461
#          Iterations 14
# 0.02:	MSE:  0.1831	ACC:  0.9960
# Optimization terminated successfully.
#          Current function value: 0.285179
#          Iterations 19
# 0.008:	MSE:  0.0704	ACC:  0.9953
# Optimization terminated successfully.
#          Current function value: 0.303118
#          Iterations 14
# 0.02:	MSE:  0.1321	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.291632
#          Iterations 19
# 0.008:	MSE:  0.0048	ACC:  0.9958
# Optimization terminated successfully.
#          Current function value: 0.291720
#          Iterations 14
# 0.02:	MSE:  0.0050	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.296659
#          Iterations 20
# 0.008:	MSE:  0.0453	ACC:  0.9972
# Optimization terminated successfully.
#          Current function value: 0.294693
#          Iterations 14
# 0.02:	MSE:  0.0137	ACC:  0.9930
# Optimization terminated successfully.
#          Current function value: 0.277282
#          Iterations 22
# 0.008:	MSE:  0.3802	ACC:  0.9909
# Optimization terminated successfully.
#          Current function value: 0.291287
#          Iterations 14
# 0.02:	MSE:  0.0022	ACC:  0.9955
# Optimization terminated successfully.
#          Current function value: 0.299807
#          Iterations 18
# 0.008:	MSE:  0.0917	ACC:  0.9962
# Optimization terminated successfully.
#          Current function value: 0.293123
#          Iterations 14
# 0.02:	MSE:  0.0022	ACC:  0.9958
# Optimization terminated successfully.
#          Current function value: 0.294806
#          Iterations 21
# 0.008:	MSE:  0.0266	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.294280
#          Iterations 14
# 0.02:	MSE:  0.0094	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.294602
#          Iterations 20
# 0.008:	MSE:  0.0177	ACC:  0.9906
# Optimization terminated successfully.
#          Current function value: 0.285860
#          Iterations 14
# 0.02:	MSE:  0.0843	ACC:  0.9942
# Optimization terminated successfully.
#          Current function value: 0.285328
#          Iterations 20
# 0.008:	MSE:  0.0520	ACC:  0.9942
# Optimization terminated successfully.
#          Current function value: 0.297393
#          Iterations 14
# 0.02:	MSE:  0.0372	ACC:  0.9954
# Optimization terminated successfully.
#          Current function value: 0.295045
#          Iterations 22
# 0.008:	MSE:  0.0226	ACC:  0.9958
# Optimization terminated successfully.
#          Current function value: 0.299170
#          Iterations 13
# 0.02:	MSE:  0.0705	ACC:  0.9954
# Optimization terminated successfully.
#          Current function value: 0.288740
#          Iterations 21
# 0.008:	MSE:  0.0130	ACC:  0.9932
# Optimization terminated successfully.
#          Current function value: 0.288377
#          Iterations 14
# 0.02:	MSE:  0.0213	ACC:  0.9971
# Optimization terminated successfully.
#          Current function value: 0.287792
#          Iterations 20
# 0.008:	MSE:  0.0330	ACC:  0.9927
# Optimization terminated successfully.
#          Current function value: 0.290335
#          Iterations 14
# 0.02:	MSE:  0.0075	ACC:  0.9923
# Optimization terminated successfully.
#          Current function value: 0.289736
#          Iterations 19
# 0.008:	MSE:  0.0158	ACC:  0.9906
# Optimization terminated successfully.
#          Current function value: 0.288153
#          Iterations 14
# 0.02:	MSE:  0.0205	ACC:  0.9964
# Optimization terminated successfully.
#          Current function value: 0.298446
#          Iterations 19
# 0.008:	MSE:  0.0639	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.293667
#          Iterations 15
# 0.02:	MSE:  0.0072	ACC:  0.9950
# Optimization terminated successfully.
#          Current function value: 0.295710
#          Iterations 20
# 0.008:	MSE:  0.0262	ACC:  0.9964
# Optimization terminated successfully.
#          Current function value: 0.294321
#          Iterations 14
# 0.02:	MSE:  0.0066	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.295475
#          Iterations 18
# 0.008:	MSE:  0.0172	ACC:  0.9951
# Optimization terminated successfully.
#          Current function value: 0.285720
#          Iterations 14
# 0.02:	MSE:  0.0650	ACC:  0.9967
# Optimization terminated successfully.
#          Current function value: 0.298165
#          Iterations 22
# 0.008:	MSE:  0.0647	ACC:  0.9965
# Optimization terminated successfully.
#          Current function value: 0.291980
#          Iterations 14
# 0.02:	MSE:  0.0030	ACC:  0.9954
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.317767
#          Iterations: 35
# 0.008:	MSE:  0.1452	ACC:  0.9903
# Optimization terminated successfully.
#          Current function value: 0.282067
#          Iterations 14
# 0.02:	MSE:  0.1326	ACC:  0.9949
# Optimization terminated successfully.
#          Current function value: 0.286406
#          Iterations 18
# 0.008:	MSE:  0.0301	ACC:  0.9940
# Optimization terminated successfully.
#          Current function value: 0.291754
#          Iterations 14
# 0.02:	MSE:  0.0024	ACC:  0.9955
# Optimization terminated successfully.
#          Current function value: 0.284462
#          Iterations 19
# 0.008:	MSE:  0.0662	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.286558
#          Iterations 14
# 0.02:	MSE:  0.0528	ACC:  0.9974
# Optimization terminated successfully.
#          Current function value: 0.287497
#          Iterations 18
# 0.008:	MSE:  0.0154	ACC:  0.9973
# Optimization terminated successfully.
#          Current function value: 0.296045
#          Iterations 14
# 0.02:	MSE:  0.0336	ACC:  0.9969
# Optimization terminated successfully.
#          Current function value: 0.291345
#          Iterations 17
# 0.008:	MSE:  0.0036	ACC:  0.9948
# Optimization terminated successfully.
#          Current function value: 0.293490
#          Iterations 14
# 0.02:	MSE:  0.0065	ACC:  0.9952
# Optimization terminated successfully.
#          Current function value: 0.291218
#          Iterations 19
# 0.008:	MSE:  0.0028	ACC:  0.9946
# Optimization terminated successfully.
#          Current function value: 0.293537
#          Iterations 14
# 0.02:	MSE:  0.0028	ACC:  0.9952
# Optimization terminated successfully.
#          Current function value: 0.285355
#          Iterations 17
# 0.008:	MSE:  0.0545	ACC:  0.9937
# Optimization terminated successfully.
#          Current function value: 0.298542
#          Iterations 14
# 0.02:	MSE:  0.0515	ACC:  0.9932
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.284982
#          Iterations 17
# 0.008:	MSE:  0.0564	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.299406
#          Iterations 14
# 0.02:	MSE:  0.0705	ACC:  0.9933
# Optimization terminated successfully.
#          Current function value: 0.286520
#          Iterations 21
# 0.008:	MSE:  0.0430	ACC:  0.9923
# Optimization terminated successfully.
#          Current function value: 0.293220
#          Iterations 14
# 0.02:	MSE:  0.0026	ACC:  0.9970
# Optimization terminated successfully.
#          Current function value: 0.293969
#          Iterations 18
# 0.008:	MSE:  0.0138	ACC:  0.9939
# Optimization terminated successfully.
#          Current function value: 0.290439
#          Iterations 14
# 0.02:	MSE:  0.0099	ACC:  0.9957
# Optimization terminated successfully.
#          Current function value: 0.298295
#          Iterations 17
# 0.008:	MSE:  0.0529	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.288346
#          Iterations 14
# 0.02:	MSE:  0.0205	ACC:  0.9961
# Optimization terminated successfully.
#          Current function value: 0.284103
#          Iterations 18
# 0.008:	MSE:  0.0852	ACC:  0.9953
# Optimization terminated successfully.
#          Current function value: 0.297584
#          Iterations 14
# 0.02:	MSE:  0.0394	ACC:  0.9930
# Optimization terminated successfully.
#          Current function value: 0.291550
#          Iterations 20
# 0.008:	MSE:  0.0040	ACC:  0.9938
# Optimization terminated successfully.
#          Current function value: 0.286647
#          Iterations 14
# 0.02:	MSE:  0.0460	ACC:  0.9963
# Optimization terminated successfully.
#          Current function value: 0.293702
#          Iterations 20
# 0.008:	MSE:  0.0084	ACC:  0.9951
# Optimization terminated successfully.
#          Current function value: 0.291966
#          Iterations 14
# 0.02:	MSE:  0.0032	ACC:  0.9949
# Optimization terminated successfully.
#          Current function value: 0.291893
#          Iterations 32
# 0.008:	MSE:  0.0055	ACC:  0.9954
# Optimization terminated successfully.
#          Current function value: 0.289860
#          Iterations 14
# 0.02:	MSE:  0.0114	ACC:  0.9950
# Optimization terminated successfully.
#          Current function value: 0.294613
#          Iterations 29
# 0.008:	MSE:  0.0251	ACC:  0.9910
# Optimization terminated successfully.
#          Current function value: 0.295882
#          Iterations 14
# 0.02:	MSE:  0.0166	ACC:  0.9969
# Optimization terminated successfully.
#          Current function value: 0.283683
#          Iterations 21
# 0.008:	MSE:  0.0877	ACC:  0.9923
# Optimization terminated successfully.
#          Current function value: 0.296316
#          Iterations 14
# 0.02:	MSE:  0.0269	ACC:  0.9954
# Optimization terminated successfully.
#          Current function value: 0.289518
#          Iterations 18
# 0.008:	MSE:  0.0053	ACC:  0.9957
# Optimization terminated successfully.
#          Current function value: 0.290694
#          Iterations 14
# 0.02:	MSE:  0.0072	ACC:  0.9971
# Optimization terminated successfully.
#          Current function value: 0.299388
#          Iterations 19
# 0.008:	MSE:  0.0861	ACC:  0.9922
# Optimization terminated successfully.
#          Current function value: 0.294592
#          Iterations 14
# 0.02:	MSE:  0.0081	ACC:  0.9967
# Optimization terminated successfully.
#          Current function value: 0.286996
#          Iterations 20
# 0.008:	MSE:  0.0256	ACC:  0.9974
# Optimization terminated successfully.
#          Current function value: 0.285330
#          Iterations 14
# 0.02:	MSE:  0.0826	ACC:  0.9955
# Optimization terminated successfully.
#          Current function value: 0.290534
#          Iterations 19
# 0.008:	MSE:  0.0072	ACC:  0.9915
# Optimization terminated successfully.
#          Current function value: 0.288864
#          Iterations 14
# 0.02:	MSE:  0.0120	ACC:  0.9970
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.300990
#          Iterations: 35
# 0.008:	MSE:  0.0059	ACC:  0.9939
# Optimization terminated successfully.
#          Current function value: 0.294410
#          Iterations 14
# 0.02:	MSE:  0.0121	ACC:  0.9923
# Optimization terminated successfully.
#          Current function value: 0.281841
#          Iterations 20
# 0.008:	MSE:  0.1098	ACC:  0.9958
# Optimization terminated successfully.
#          Current function value: 0.294582
#          Iterations 14
# 0.02:	MSE:  0.0055	ACC:  0.9968
# Optimization terminated successfully.
#          Current function value: 0.299326
#          Iterations 20
# 0.008:	MSE:  0.0903	ACC:  0.9932
# Optimization terminated successfully.
#          Current function value: 0.293720
#          Iterations 14
# 0.02:	MSE:  0.0030	ACC:  0.9955
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.284817
#          Iterations 23
# 0.008:	MSE:  0.0638	ACC:  0.9933
# Optimization terminated successfully.
#          Current function value: 0.293272
#          Iterations 14
# 0.02:	MSE:  0.0027	ACC:  0.9970
# Optimization terminated successfully.
#          Current function value: 0.297652
#          Iterations 19
# 0.008:	MSE:  0.0541	ACC:  0.9915
# Optimization terminated successfully.
#          Current function value: 0.289935
#          Iterations 14
# 0.02:	MSE:  0.0037	ACC:  0.9962
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.296719
#          Iterations: 35
# 0.008:	MSE:  0.0340	ACC:  0.9933
# Optimization terminated successfully.
#          Current function value: 0.291660
#          Iterations 14
# 0.02:	MSE:  0.0030	ACC:  0.9951
# Optimization terminated successfully.
#          Current function value: 0.296141
#          Iterations 21
# 0.008:	MSE:  0.0216	ACC:  0.9957
# Optimization terminated successfully.
#          Current function value: 0.283550
#          Iterations 14
# 0.02:	MSE:  0.0761	ACC:  0.9966
# Optimization terminated successfully.
#          Current function value: 0.291981
#          Iterations 19
# 0.008:	MSE:  0.0021	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.294229
#          Iterations 14
# 0.02:	MSE:  0.0102	ACC:  0.9961
# Optimization terminated successfully.
#          Current function value: 0.293587
#          Iterations 18
# 0.008:	MSE:  0.0128	ACC:  0.9930
# Optimization terminated successfully.
#          Current function value: 0.299901
#          Iterations 13
# 0.02:	MSE:  0.0779	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.292081
#          Iterations 18
# 0.008:	MSE:  0.0078	ACC:  0.9912
# Optimization terminated successfully.
#          Current function value: 0.296802
#          Iterations 14
# 0.02:	MSE:  0.0338	ACC:  0.9943
# Optimization terminated successfully.
#          Current function value: 0.285695
#          Iterations 17
# 0.008:	MSE:  0.0587	ACC:  0.9932
# Optimization terminated successfully.
#          Current function value: 0.290044
#          Iterations 14
# 0.02:	MSE:  0.0039	ACC:  0.9975
# Optimization terminated successfully.
#          Current function value: 0.294402
#          Iterations 16
# 0.008:	MSE:  0.0178	ACC:  0.9926
# Optimization terminated successfully.
#          Current function value: 0.283008
#          Iterations 16
# 0.02:	MSE:  0.1261	ACC:  0.9926
# Optimization terminated successfully.
#          Current function value: 0.289970
#          Iterations 21
# 0.008:	MSE:  0.0080	ACC:  0.9916
# Optimization terminated successfully.
#          Current function value: 0.293594
#          Iterations 14
# 0.02:	MSE:  0.0046	ACC:  0.9945
# Optimization terminated successfully.
#          Current function value: 0.295762
#          Iterations 18
# 0.008:	MSE:  0.0188	ACC:  0.9960
# Optimization terminated successfully.
#          Current function value: 0.281506
#          Iterations 15
# 0.02:	MSE:  0.1702	ACC:  0.9924
# Optimization terminated successfully.
#          Current function value: 0.293985
#          Iterations 17
# 0.008:	MSE:  0.0134	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.287695
#          Iterations 14
# 0.02:	MSE:  0.0426	ACC:  0.9965
# Optimization terminated successfully.
#          Current function value: 0.287849
#          Iterations 20
# 0.008:	MSE:  0.0161	ACC:  0.9966
# Optimization terminated successfully.
#          Current function value: 0.289729
#          Iterations 14
# 0.02:	MSE:  0.0139	ACC:  0.9953
# Optimization terminated successfully.
#          Current function value: 0.287774
#          Iterations 19
# 0.008:	MSE:  0.0264	ACC:  0.9944
# Optimization terminated successfully.
#          Current function value: 0.298750
#          Iterations 14
# 0.02:	MSE:  0.0597	ACC:  0.9934
# Optimization terminated successfully.
#          Current function value: 0.292057
#          Iterations 19
# 0.008:	MSE:  0.0035	ACC:  0.9946
# Optimization terminated successfully.
#          Current function value: 0.298812
#          Iterations 15
# 0.02:	MSE:  0.0494	ACC:  0.9927
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.298507
#          Iterations: 35
# 0.008:	MSE:  0.0679	ACC:  0.9941
# Optimization terminated successfully.
#          Current function value: 0.293236
#          Iterations 14
# 0.02:	MSE:  0.0030	ACC:  0.9953
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.413722
#          Iterations: 35
# 0.008:	MSE:  0.2261	ACC:  0.9835
# Optimization terminated successfully.
#          Current function value: 0.282781
#          Iterations 14
# 0.02:	MSE:  0.1518	ACC:  0.9948
# Optimization terminated successfully.
#          Current function value: 0.298182
#          Iterations 27
# 0.008:	MSE:  0.0567	ACC:  0.9948
# Optimization terminated successfully.
#          Current function value: 0.288677
#          Iterations 14
# 0.02:	MSE:  0.0135	ACC:  0.9951
# Optimization terminated successfully.
#          Current function value: 0.294451
#          Iterations 18
# 0.008:	MSE:  0.0167	ACC:  0.9927
# Optimization terminated successfully.
#          Current function value: 0.288861
#          Iterations 14
# 0.02:	MSE:  0.0170	ACC:  0.9919
# Optimization terminated successfully.
#          Current function value: 0.288218
#          Iterations 22
# 0.008:	MSE:  0.0191	ACC:  0.9912
# Optimization terminated successfully.
#          Current function value: 0.290080
#          Iterations 14
# 0.02:	MSE:  0.0075	ACC:  0.9964
# Optimization terminated successfully.
#          Current function value: 0.293535
#          Iterations 20
# 0.008:	MSE:  0.0090	ACC:  0.9940
# Optimization terminated successfully.
#          Current function value: 0.291410
#          Iterations 15
# 0.02:	MSE:  0.0011	ACC:  0.9966
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.302747
#          Iterations: 35
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# 0.008:	MSE:  0.0109	ACC:  0.9909
# Optimization terminated successfully.
#          Current function value: 0.294764
#          Iterations 14
# 0.02:	MSE:  0.0119	ACC:  0.9945
# Optimization terminated successfully.
#          Current function value: 0.290673
#          Iterations 19
# 0.008:	MSE:  0.0019	ACC:  0.9965
# Optimization terminated successfully.
#          Current function value: 0.284718
#          Iterations 14
# 0.02:	MSE:  0.0793	ACC:  0.9959
# Optimization terminated successfully.
#          Current function value: 0.292714
#          Iterations 15
# 0.008:	MSE:  0.0068	ACC:  0.9932
# Optimization terminated successfully.
#          Current function value: 0.284094
#          Iterations 14
# 0.02:	MSE:  0.0899	ACC:  0.9952
# Optimization terminated successfully.
#          Current function value: 0.294836
#          Iterations 18
# 0.008:	MSE:  0.0141	ACC:  0.9981
# Optimization terminated successfully.
#          Current function value: 0.289154
#          Iterations 14
# 0.02:	MSE:  0.0066	ACC:  0.9966
# Optimization terminated successfully.
#          Current function value: 0.292975
#          Iterations 17
# 0.008:	MSE:  0.0080	ACC:  0.9921
# Optimization terminated successfully.
#          Current function value: 0.288275
#          Iterations 14
# 0.02:	MSE:  0.0246	ACC:  0.9943
# Optimization terminated successfully.
#          Current function value: 0.291767
#          Iterations 19
# 0.008:	MSE:  0.0072	ACC:  0.9947
# Optimization terminated successfully.
#          Current function value: 0.290998
#          Iterations 14
# 0.02:	MSE:  0.0030	ACC:  0.9951
# Optimization terminated successfully.
#          Current function value: 0.294350
#          Iterations 18
# 0.008:	MSE:  0.0176	ACC:  0.9968
# Optimization terminated successfully.
#          Current function value: 0.292500
#          Iterations 14
# 0.02:	MSE:  0.0024	ACC:  0.9952
# Optimization terminated successfully.
#          Current function value: 0.293572
#          Iterations 15
# 0.008:	MSE:  0.0091	ACC:  0.9920
# Optimization terminated successfully.
#          Current function value: 0.289945
#          Iterations 14
# 0.02:	MSE:  0.0033	ACC:  0.9961
# Optimization terminated successfully.
#          Current function value: 0.289318
#          Iterations 16
# 0.008:	MSE:  0.0093	ACC:  0.9945
# Optimization terminated successfully.
#          Current function value: 0.288220
#          Iterations 14
# 0.02:	MSE:  0.0388	ACC:  0.9944
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.315428
#          Iterations: 35
# 0.008:	MSE:  0.0167	ACC:  0.9889
# Optimization terminated successfully.
#          Current function value: 0.293966
#          Iterations 14
# 0.02:	MSE:  0.0079	ACC:  0.9961
# Optimization terminated successfully.
#          Current function value: 0.289410
#          Iterations 17
# 0.008:	MSE:  0.0082	ACC:  0.9923
# Optimization terminated successfully.
#          Current function value: 0.286110
#          Iterations 14
# 0.02:	MSE:  0.0448	ACC:  0.9951
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.312227
#          Iterations: 35
# 0.008:	MSE:  0.0953	ACC:  0.9902
# Optimization terminated successfully.
#          Current function value: 0.292365
#          Iterations 14
# 0.02:	MSE:  0.0033	ACC:  0.9945
# Optimization terminated successfully.
#          Current function value: 0.292455
#          Iterations 19
# 0.008:	MSE:  0.0066	ACC:  0.9917
# Optimization terminated successfully.
#          Current function value: 0.293260
#          Iterations 14
# 0.02:	MSE:  0.0043	ACC:  0.9937
# Optimization terminated successfully.
#          Current function value: 0.295213
#          Iterations 20
# 0.008:	MSE:  0.0419	ACC:  0.9907
# Optimization terminated successfully.
#          Current function value: 0.296433
#          Iterations 14
# 0.02:	MSE:  0.0213	ACC:  0.9936
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.309301
#          Iterations: 35
# 0.008:	MSE:  0.0492	ACC:  0.9894
# Optimization terminated successfully.
#          Current function value: 0.292864
#          Iterations 14
# 0.02:	MSE:  0.0022	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.290901
#          Iterations 18
# 0.008:	MSE:  0.0030	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.286315
#          Iterations 14
# 0.02:	MSE:  0.0384	ACC:  0.9962
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.305823
#          Iterations: 35
# 0.008:	MSE:  0.0247	ACC:  0.9873
# Optimization terminated successfully.
#          Current function value: 0.288741
#          Iterations 14
# 0.02:	MSE:  0.0179	ACC:  0.9960
# Optimization terminated successfully.
#          Current function value: 0.290648
#          Iterations 21
# 0.008:	MSE:  0.0107	ACC:  0.9907
# Optimization terminated successfully.
#          Current function value: 0.287129
#          Iterations 14
# 0.02:	MSE:  0.0360	ACC:  0.9952
# Optimization terminated successfully.
#          Current function value: 0.291675
#          Iterations 20
# 0.008:	MSE:  0.0131	ACC:  0.9887
# Optimization terminated successfully.
#          Current function value: 0.297200
#          Iterations 14
# 0.02:	MSE:  0.0331	ACC:  0.9972
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.290848
#          Iterations: 35
# 0.008:	MSE:  0.0037	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.287917
#          Iterations 14
# 0.02:	MSE:  0.0244	ACC:  0.9950
# Optimization terminated successfully.
#          Current function value: 0.292621
#          Iterations 17
# 0.008:	MSE:  0.0063	ACC:  0.9949
# Optimization terminated successfully.
#          Current function value: 0.287675
#          Iterations 14
# 0.02:	MSE:  0.0217	ACC:  0.9935
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Optimization terminated successfully.
#          Current function value: 0.283600
#          Iterations 20
# 0.008:	MSE:  0.1083	ACC:  0.9914
# Optimization terminated successfully.
#          Current function value: 0.289209
#          Iterations 15
# 0.02:	MSE:  0.0131	ACC:  0.9924
# Optimization terminated successfully.
#          Current function value: 0.294465
#          Iterations 19
# 0.008:	MSE:  0.0132	ACC:  0.9972
# Optimization terminated successfully.
#          Current function value: 0.293613
#          Iterations 14
# 0.02:	MSE:  0.0061	ACC:  0.9956
# Optimization terminated successfully.
#          Current function value: 0.293701
#          Iterations 17
# 0.008:	MSE:  0.0094	ACC:  0.9925
# Optimization terminated successfully.
#          Current function value: 0.292628
#          Iterations 14
# 0.02:	MSE:  0.0028	ACC:  0.9967
# Optimization terminated successfully.
#          Current function value: 0.297302
#          Iterations 20
# 0.008:	MSE:  0.0418	ACC:  0.9932
# Optimization terminated successfully.
#          Current function value: 0.288057
#          Iterations 15
# 0.02:	MSE:  0.0182	ACC:  0.9954
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.303255
#          Iterations: 35
# 0.008:	MSE:  0.0082	ACC:  0.9911
# Optimization terminated successfully.
#          Current function value: 0.286807
#          Iterations 14
# 0.02:	MSE:  0.0646	ACC:  0.9965
# Optimization terminated successfully.
#          Current function value: 0.286031
#          Iterations 18
# 0.008:	MSE:  0.0321	ACC:  0.9946
# Optimization terminated successfully.
#          Current function value: 0.292648
#          Iterations 14
# 0.02:	MSE:  0.0035	ACC:  0.9958
# Optimization terminated successfully.
#          Current function value: 0.290646
#          Iterations 16
# 0.008:	MSE:  0.0017	ACC:  0.9963
# Optimization terminated successfully.
#          Current function value: 0.297509
#          Iterations 14
# 0.02:	MSE:  0.0355	ACC:  0.9979
# Optimization terminated successfully.
#          Current function value: 0.288878
#          Iterations 33
# 0.008:	MSE:  0.0088	ACC:  0.9946
# Optimization terminated successfully.
#          Current function value: 0.287857
#          Iterations 14
# 0.02:	MSE:  0.0225	ACC:  0.9938
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
results_DF = pd.DataFrame(results)
results_DF.head()
# Out:
#    0      1         2         3
# 0  0  0.008  0.030667  0.992554
# 1  0  0.020  0.442217  0.994171
# 2  1  0.008  0.110873  0.992241
# 3  1  0.020  0.008605  0.993573
# 4  2  0.008  0.003825  0.994023

# %%
mse_data = []
for sigma in sigmam_list:
    mse_data.append(np.log(results_DF.loc[results_DF[1] == sigma, 2]))
plt.boxplot(mse_data)
plt.title("MSE Results")
plt.plot()
# Out:
# []

# %%
acc_data = []
for sigma in sigmam_list:
    acc_data.append((results_DF.loc[results_DF[1] == sigma, 3]))
plt.boxplot(acc_data)
plt.title("ACC Results")
plt.plot()
# Out:
# []

# %%
plt.boxplot(mse_data)
plt.title("MSE Results")
plt.plot()

# %%
results_DF.to_csv("/Users/helenology/Desktop/test.csv")
